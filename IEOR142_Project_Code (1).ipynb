# %% [markdown]
# # Data Cleaning

# %%
import numpy as np 
import pandas as pd
from sklearn import datasets 
from sklearn.metrics import accuracy_score
from sklearn import linear_model as lm 
import statsmodels.api as sm 
import statsmodels.formula.api as smf 
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import make_scorer 
from sklearn.metrics import mean_absolute_error as MAE
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score 
from sklearn.model_selection import train_test_split
import regex as re
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.feature_extraction import DictVectorizer
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV, ParameterGrid
from sklearn.metrics import roc_curve, auc
from sklearn import preprocessing
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import GradientBoostingClassifier

import warnings
warnings.filterwarnings("ignore")

# %%
grammy = pd.read_csv("grammySongs_1999-2019.csv")
grammy_noms = pd.read_csv("the_grammy_awards.csv")
bb99 = pd.read_csv("billboardHot100_1999-2019.csv")
songs99 = pd.read_csv("songAttributes_1999-2019.csv")

# %%
grammy.head()
# Out:
#    Unnamed: 0  X                     GrammyAward  GrammyYear  \
# 0           1  0              Record Of The Year        2018
# 1           2  1                Song Of The Year        2018
# 2           3  2       Best Pop Solo Performance        2018
# 3           4  3  Best Pop Duo/Group Performance        2018
# 4           5  4            Best Dance Recording        2018
#
#                     Genre                                       Name  \
# 0                 General                            this is America
# 1                 General                            this is America
# 2                     Pop  Joanne (where Do you Think You're Goin'?)
# 3                     Pop                                    Shallow
# 4  Dance/Electronic Music                                Electricity
#
#                                               Artist
# 0                                   Childish Gambino
# 1                                   Childish Gambino
# 2                                          Lady Gaga
# 3                         Lady Gaga & Bradley Cooper
# 4  Silk City & Dua Lipa Featuring Diplo & Mark Ro...

# %%
len(songs99)
# Out:
# 154931

# %%
songs99.head()
# Out:
#    Unnamed: 0  Acousticness                             Album  \
# 0           0      0.000728  Collective Soul (Deluxe Version)
# 1           1      0.018200  Collective Soul (Deluxe Version)
# 2           2      0.000473  Collective Soul (Deluxe Version)
# 3           3      0.000970  Collective Soul (Deluxe Version)
# 4           4      0.000036  Collective Soul (Deluxe Version)
#
#             Artist  Danceability  Duration  Energy  Explicit  \
# 0  Collective Soul         0.520    234947   0.904     False
# 1  Collective Soul         0.581    239573   0.709     False
# 2  Collective Soul         0.572    198400   0.918     False
# 3  Collective Soul         0.596    231453   0.661     False
# 4  Collective Soul         0.520    222520   0.808     False
#
#    Instrumentalness  Liveness  Loudness  Mode               Name  Popularity  \
# 0          0.010300    0.0634    -5.030     1  Welcome All Again          35
# 1          0.000664    0.1740    -4.909     1              Fuzzy          31
# 2          0.000431    0.0977    -3.324     0                Dig          30
# 3          0.000033    0.1130    -5.051     1                You          35
# 4          0.000010    0.0800    -4.553     0            My Days          21
#
#    Speechiness    Tempo  TimeSignature  Valence
# 0       0.0309  106.022              4    0.365
# 1       0.0282  120.027              4    0.408
# 2       0.0559  144.061              4    0.370
# 3       0.0254  111.975              4    0.183
# 4       0.0318   92.721              4    0.666

# %%
songs99[songs99["Artist"] == "Ed Sheeran"]
# Out:
#         Unnamed: 0  Acousticness                        Album      Artist  \
# 154812           0      0.877000           x (Deluxe Edition)  Ed Sheeran
# 154813           1      0.556000           x (Deluxe Edition)  Ed Sheeran
# 154814           2      0.304000           x (Deluxe Edition)  Ed Sheeran
# 154815           3      0.011300           x (Deluxe Edition)  Ed Sheeran
# 154816           4      0.175000           x (Deluxe Edition)  Ed Sheeran
# ...            ...           ...                          ...         ...
# 154926         114      0.333000  No.6 Collaborations Project  Ed Sheeran
# 154927         115      0.314000  No.6 Collaborations Project  Ed Sheeran
# 154928         116      0.467000  No.6 Collaborations Project  Ed Sheeran
# 154929         117      0.110000  No.6 Collaborations Project  Ed Sheeran
# 154930         118      0.000245  No.6 Collaborations Project  Ed Sheeran
#
#         Danceability  Duration  Energy  Explicit  Instrumentalness  Liveness  \
# 154812         0.464    252760   0.321     False          0.000000    0.0789
# 154813         0.697    244573   0.377     False          0.000000    0.0999
# 154814         0.818    235382   0.670     False          0.000001    0.0601
# 154815         0.806    219840   0.608     False          0.000000    0.6350
# 154816         0.791    225533   0.669     False          0.000000    0.3300
# ...              ...       ...     ...       ...               ...       ...
# 154926         0.747    200733   0.649     False          0.000000    0.1720
# 154927         0.469    204507   0.631     False          0.000000    0.1400
# 154928         0.778    212307   0.590     False          0.000000    0.0902
# 154929         0.726    190293   0.731     False          0.000003    0.0928
# 154930         0.631    209120   0.796     False          0.011500    0.3800
#
#         Loudness  Mode                                               Name  \
# 154812   -11.120     1                                                One
# 154813    -7.755     1                                         I'm a Mess
# 154814    -4.451     0                                               Sing
# 154815    -7.008     1                                              Don't
# 154816    -7.189     0                                               Nina
# ...          ...   ...                                                ...
# 154926    -6.218     0         Nothing On You (feat. Paulo Londra & Dave)
# 154927    -6.569     0             I Don't Want Your Money (feat. H.E.R.)
# 154928    -5.548     1  1000 Nights (feat. Meek Mill & A Boogie Wit da...
# 154929    -6.304     0             Way To Break My Heart (feat. Skrillex)
# 154930    -5.350     1           BLOW (with Chris Stapleton & Bruno Mars)
#
#         Popularity  Speechiness    Tempo  TimeSignature  Valence
# 154812          67       0.0418   93.528              4    0.306
# 154813          70       0.0397  138.754              4    0.336
# 154814          71       0.0472  119.988              4    0.939
# 154815          74       0.0659   95.049              4    0.849
# 154816          61       0.1460   92.013              4    0.809
# ...            ...          ...      ...            ...      ...
# 154926          80       0.2190   88.011              4    0.840
# 154927          74       0.0853   91.418              4    0.763
# 154928          75       0.2700   97.995              4    0.515
# 154929          73       0.1590  170.125              4    0.430
# 154930          72       0.0401   92.469              4    0.596
#
# [119 rows x 18 columns]

# %%
len(bb99)
# Out:
# 97225

# %%
bb99.head()
# Out:
#    Unnamed: 0                       Artists           Name  Weekly.rank  \
# 0           1                      Lil Nas,  Old Town Road            1
# 1           2  Shawn Mendes, Camila Cabello       Senorita            2
# 2           3                 Billie Eilish        Bad Guy            3
# 3           4                        Khalid           Talk            4
# 4           5     Ed Sheeran, Justin Bieber   I Don't Care            5
#
#    Peak.position  Weeks.on.chart        Week              Date  \
# 0            1.0             7.0  2019-07-06     April 5, 2019
# 1            NaN             NaN  2019-07-06     June 21, 2019
# 2            2.0            13.0  2019-07-06    March 29, 2019
# 3            3.0            20.0  2019-07-06  February 7, 2019
# 4            2.0             7.0  2019-07-06      May 10, 2019
#
#                                                Genre  \
# 0  Country,Atlanta,Alternative Country,Hip-Hop,Tr...
# 1                                                Pop
# 2  Hip-Hop,Dark Pop,House,Trap,Memes,Alternative ...
# 3                                      Synth-Pop,Pop
# 4                      Canada,UK,Dance,Dance-Pop,Pop
#
#                                      Writing.Credits  \
# 0  Jozzy, Atticus ross, Trent reznor, Billy ray c...
# 1  Cashmere cat, Jack patterson, Charli xcx, Benn...
# 2                             Billie eilish, Finneas
# 3              Howard lawrence, Guy lawrence, Khalid
# 4  Ed sheeran, Justin bieber, Shellback, Max mart...
#
#                                               Lyrics         Features
# 0  Old Town Road Remix \nOh, oh-oh\nOh\nYeah, I'm...  Billy Ray Cyrus
# 1  Senorita \nI love it when you call me senorita...              NaN
# 2  bad guy \nWhite shirt now red, my bloody nose\...              NaN
# 3  Talk \nCan we just talk? Can we just talk?\nTa...              NaN
# 4  I Don't Care \nI'm at a party I don't wanna be...              NaN

# %%
bb99_2 = bb99.drop(columns = ["Unnamed: 0", "Writing.Credits", "Lyrics", "Features"])

# %%
#extracted year from chart week
pattern = '\d{4}'
years = list()
for x in bb99_2["Week"]:
    match = re.search(pattern, x)
    year = match.group()
    years.append(int(year))
bb99_2["Year"] = years
bb99_2
# Out:
#                             Artists                      Name  Weekly.rank  \
# 0                          Lil Nas,             Old Town Road            1
# 1      Shawn Mendes, Camila Cabello                  Senorita            2
# 2                     Billie Eilish                   Bad Guy            3
# 3                            Khalid                      Talk            4
# 4         Ed Sheeran, Justin Bieber              I Don't Care            5
# ...                             ...                       ...          ...
# 97220                     Vitamin C                     Smile           95
# 97221               Collective Soul                     Heavy           96
# 97222         Mary Chapin Carpenter               Almost Home           97
# 97223                             Q             Vivrant Thing           98
# 97224                 The Offspring  Why Don't You Get A Job?          100
#
#        Peak.position  Weeks.on.chart        Week              Date  \
# 0                1.0             7.0  2019-07-06     April 5, 2019
# 1                NaN             NaN  2019-07-06     June 21, 2019
# 2                2.0            13.0  2019-07-06    March 29, 2019
# 3                3.0            20.0  2019-07-06  February 7, 2019
# 4                2.0             7.0  2019-07-06      May 10, 2019
# ...              ...             ...         ...               ...
# 97220            NaN             NaN  1999-07-12               NaN
# 97221           73.0            20.0  1999-07-12               NaN
# 97222            NaN             NaN  1999-07-12               NaN
# 97223            NaN             NaN  1999-07-12               NaN
# 97224           74.0            15.0  1999-07-12               NaN
#
#                                                    Genre  Year
# 0      Country,Atlanta,Alternative Country,Hip-Hop,Tr...  2019
# 1                                                    Pop  2019
# 2      Hip-Hop,Dark Pop,House,Trap,Memes,Alternative ...  2019
# 3                                          Synth-Pop,Pop  2019
# 4                          Canada,UK,Dance,Dance-Pop,Pop  2019
# ...                                                  ...   ...
# 97220                                        Jamaica,Pop  1999
# 97221                      Hockey,Gaming,Soundtrack,Rock  1999
# 97222                                        Country,Pop  1999
# 97223                                                Rap  1999
# 97224                                 Ska,Punk Rock,Rock  1999
#
# [97225 rows x 9 columns]

# %%
bb99_3 = bb99_2.drop(columns = ["Date", "Week", "Genre"])
bb99_3.head()
# Out:
#                         Artists           Name  Weekly.rank  Peak.position  \
# 0                      Lil Nas,  Old Town Road            1            1.0
# 1  Shawn Mendes, Camila Cabello       Senorita            2            NaN
# 2                 Billie Eilish        Bad Guy            3            2.0
# 3                        Khalid           Talk            4            3.0
# 4     Ed Sheeran, Justin Bieber   I Don't Care            5            2.0
#
#    Weeks.on.chart  Year
# 0             7.0  2019
# 1             NaN  2019
# 2            13.0  2019
# 3            20.0  2019
# 4             7.0  2019

# %%
bb10s = bb99_3[bb99_3['Year'] >= 2010]
bb10s.head()
# Out:
#                         Artists           Name  Weekly.rank  Peak.position  \
# 0                      Lil Nas,  Old Town Road            1            1.0
# 1  Shawn Mendes, Camila Cabello       Senorita            2            NaN
# 2                 Billie Eilish        Bad Guy            3            2.0
# 3                        Khalid           Talk            4            3.0
# 4     Ed Sheeran, Justin Bieber   I Don't Care            5            2.0
#
#    Weeks.on.chart  Year
# 0             7.0  2019
# 1             NaN  2019
# 2            13.0  2019
# 3            20.0  2019
# 4             7.0  2019

# %%
bb10s.drop_duplicates(subset = ["Artists", "Name"]).groupby("Year").count()
# Out:
#       Artists  Name  Weekly.rank  Peak.position  Weeks.on.chart
# Year
# 2010      432   432          432            288             288
# 2011      450   450          450            299             299
# 2012      331   331          331            261             261
# 2013      353   353          353            282             282
# 2014      324   324          324            273             273
# 2015      362   362          362            287             287
# 2016      387   387          387            316             316
# 2017      441   441          441            320             320
# 2018      569   569          569            376             376
# 2019      352   352          352            271             271

# %%
bb_song = pd.merge(bb10s, songs99, left_on = ["Name", "Artists"],
                  right_on = ["Name", "Artist"])

# %%
bb_song.head(40)
# Out:
#                 Artists                    Name  Weekly.rank  Peak.position  \
# 0        Jonas Brothers                  Sucker            6            1.0
# 1        Jonas Brothers                  Sucker            6            1.0
# 2        Jonas Brothers                  Sucker            4            1.0
# 3        Jonas Brothers                  Sucker            5            1.0
# 4        Jonas Brothers                  Sucker            5            1.0
# 5        Jonas Brothers                  Sucker            4            1.0
# 6        Jonas Brothers                  Sucker            3            1.0
# 7        Jonas Brothers                  Sucker            4            1.0
# 8        Jonas Brothers                  Sucker            4            1.0
# 9        Jonas Brothers                  Sucker            5            1.0
# 10       Jonas Brothers                  Sucker            6            1.0
# 11       Jonas Brothers                  Sucker            6            1.0
# 12       Jonas Brothers                  Sucker            8            1.0
# 13       Jonas Brothers                  Sucker            9            1.0
# 14       Jonas Brothers                  Sucker            8            1.0
# 15       Jonas Brothers                  Sucker            6            1.0
# 16       Jonas Brothers                  Sucker            1            1.0
# 17         Taylor Swift   You Need To Calm Down           13            2.0
# 18         Taylor Swift   You Need To Calm Down            2            NaN
# 19  Panic! At The Disco  Hey Look Ma, I Made It           24           24.0
# 20  Panic! At The Disco  Hey Look Ma, I Made It           24           24.0
# 21  Panic! At The Disco  Hey Look Ma, I Made It           31           31.0
# 22  Panic! At The Disco  Hey Look Ma, I Made It           39           39.0
# 23  Panic! At The Disco  Hey Look Ma, I Made It           40           40.0
# 24  Panic! At The Disco  Hey Look Ma, I Made It           47           41.0
# 25  Panic! At The Disco  Hey Look Ma, I Made It           41           41.0
# 26  Panic! At The Disco  Hey Look Ma, I Made It           59           59.0
# 27  Panic! At The Disco  Hey Look Ma, I Made It           66           66.0
# 28  Panic! At The Disco  Hey Look Ma, I Made It           80           80.0
# 29  Panic! At The Disco  Hey Look Ma, I Made It           96            NaN
# 30            Lee Brice                   Rumor           26           25.0
# 31            Lee Brice                   Rumor           25           25.0
# 32            Lee Brice                   Rumor           36           36.0
# 33            Lee Brice                   Rumor           37           37.0
# 34            Lee Brice                   Rumor           41           41.0
# 35            Lee Brice                   Rumor           45           45.0
# 36            Lee Brice                   Rumor           53           53.0
# 37            Lee Brice                   Rumor           57           57.0
# 38            Lee Brice                   Rumor           61           61.0
# 39            Lee Brice                   Rumor           67           67.0
#
#     Weeks.on.chart  Year  Unnamed: 0  Acousticness                Album  \
# 0             17.0  2019          12       0.04270     Happiness Begins
# 1             16.0  2019          12       0.04270     Happiness Begins
# 2             15.0  2019          12       0.04270     Happiness Begins
# 3             14.0  2019          12       0.04270     Happiness Begins
# 4             13.0  2019          12       0.04270     Happiness Begins
# 5             12.0  2019          12       0.04270     Happiness Begins
# 6             11.0  2019          12       0.04270     Happiness Begins
# 7             10.0  2019          12       0.04270     Happiness Begins
# 8              9.0  2019          12       0.04270     Happiness Begins
# 9              8.0  2019          12       0.04270     Happiness Begins
# 10             7.0  2019          12       0.04270     Happiness Begins
# 11             6.0  2019          12       0.04270     Happiness Begins
# 12             5.0  2019          12       0.04270     Happiness Begins
# 13             4.0  2019          12       0.04270     Happiness Begins
# 14             3.0  2019          12       0.04270     Happiness Begins
# 15             2.0  2019          12       0.04270     Happiness Begins
# 16             1.0  2019          12       0.04270     Happiness Begins
# 17             2.0  2019         113       0.00929                Lover
# 18             NaN  2019         113       0.00929                Lover
# 19            11.0  2019          80       0.01370  Pray for the Wicked
# 20            10.0  2019          80       0.01370  Pray for the Wicked
# 21             9.0  2019          80       0.01370  Pray for the Wicked
# 22             8.0  2019          80       0.01370  Pray for the Wicked
# 23             7.0  2019          80       0.01370  Pray for the Wicked
# 24             6.0  2019          80       0.01370  Pray for the Wicked
# 25             5.0  2019          80       0.01370  Pray for the Wicked
# 26             4.0  2019          80       0.01370  Pray for the Wicked
# 27             3.0  2019          80       0.01370  Pray for the Wicked
# 28             2.0  2019          80       0.01370  Pray for the Wicked
# 29             NaN  2019          80       0.01370  Pray for the Wicked
# 30            16.0  2019          36       0.74900            Lee Brice
# 31            15.0  2019          36       0.74900            Lee Brice
# 32            14.0  2019          36       0.74900            Lee Brice
# 33            13.0  2019          36       0.74900            Lee Brice
# 34            12.0  2019          36       0.74900            Lee Brice
# 35            11.0  2019          36       0.74900            Lee Brice
# 36            10.0  2019          36       0.74900            Lee Brice
# 37             9.0  2019          36       0.74900            Lee Brice
# 38             8.0  2019          36       0.74900            Lee Brice
# 39             7.0  2019          36       0.74900            Lee Brice
#
#                  Artist  ...  Explicit  Instrumentalness  Liveness  Loudness  \
# 0        Jonas Brothers  ...     False               0.0    0.1060    -5.065
# 1        Jonas Brothers  ...     False               0.0    0.1060    -5.065
# 2        Jonas Brothers  ...     False               0.0    0.1060    -5.065
# 3        Jonas Brothers  ...     False               0.0    0.1060    -5.065
# 4        Jonas Brothers  ...     False               0.0    0.1060    -5.065
# 5        Jonas Brothers  ...     False               0.0    0.1060    -5.065
# 6        Jonas Brothers  ...     False               0.0    0.1060    -5.065
# 7        Jonas Brothers  ...     False               0.0    0.1060    -5.065
# 8        Jonas Brothers  ...     False               0.0    0.1060    -5.065
# 9        Jonas Brothers  ...     False               0.0    0.1060    -5.065
# 10       Jonas Brothers  ...     False               0.0    0.1060    -5.065
# 11       Jonas Brothers  ...     False               0.0    0.1060    -5.065
# 12       Jonas Brothers  ...     False               0.0    0.1060    -5.065
# 13       Jonas Brothers  ...     False               0.0    0.1060    -5.065
# 14       Jonas Brothers  ...     False               0.0    0.1060    -5.065
# 15       Jonas Brothers  ...     False               0.0    0.1060    -5.065
# 16       Jonas Brothers  ...     False               0.0    0.1060    -5.065
# 17         Taylor Swift  ...     False               0.0    0.0637    -5.617
# 18         Taylor Swift  ...     False               0.0    0.0637    -5.617
# 19  Panic! At The Disco  ...     False               0.0    0.1210    -3.337
# 20  Panic! At The Disco  ...     False               0.0    0.1210    -3.337
# 21  Panic! At The Disco  ...     False               0.0    0.1210    -3.337
# 22  Panic! At The Disco  ...     False               0.0    0.1210    -3.337
# 23  Panic! At The Disco  ...     False               0.0    0.1210    -3.337
# 24  Panic! At The Disco  ...     False               0.0    0.1210    -3.337
# 25  Panic! At The Disco  ...     False               0.0    0.1210    -3.337
# 26  Panic! At The Disco  ...     False               0.0    0.1210    -3.337
# 27  Panic! At The Disco  ...     False               0.0    0.1210    -3.337
# 28  Panic! At The Disco  ...     False               0.0    0.1210    -3.337
# 29  Panic! At The Disco  ...     False               0.0    0.1210    -3.337
# 30            Lee Brice  ...     False               0.0    0.1150    -6.857
# 31            Lee Brice  ...     False               0.0    0.1150    -6.857
# 32            Lee Brice  ...     False               0.0    0.1150    -6.857
# 33            Lee Brice  ...     False               0.0    0.1150    -6.857
# 34            Lee Brice  ...     False               0.0    0.1150    -6.857
# 35            Lee Brice  ...     False               0.0    0.1150    -6.857
# 36            Lee Brice  ...     False               0.0    0.1150    -6.857
# 37            Lee Brice  ...     False               0.0    0.1150    -6.857
# 38            Lee Brice  ...     False               0.0    0.1150    -6.857
# 39            Lee Brice  ...     False               0.0    0.1150    -6.857
#
#     Mode  Popularity  Speechiness    Tempo  TimeSignature  Valence
# 0      0          81       0.0588  137.958              4    0.952
# 1      0          81       0.0588  137.958              4    0.952
# 2      0          81       0.0588  137.958              4    0.952
# 3      0          81       0.0588  137.958              4    0.952
# 4      0          81       0.0588  137.958              4    0.952
# 5      0          81       0.0588  137.958              4    0.952
# 6      0          81       0.0588  137.958              4    0.952
# 7      0          81       0.0588  137.958              4    0.952
# 8      0          81       0.0588  137.958              4    0.952
# 9      0          81       0.0588  137.958              4    0.952
# 10     0          81       0.0588  137.958              4    0.952
# 11     0          81       0.0588  137.958              4    0.952
# 12     0          81       0.0588  137.958              4    0.952
# 13     0          81       0.0588  137.958              4    0.952
# 14     0          81       0.0588  137.958              4    0.952
# 15     0          81       0.0588  137.958              4    0.952
# 16     0          81       0.0588  137.958              4    0.952
# 17     1          89       0.0553   85.026              4    0.714
# 18     1          89       0.0553   85.026              4    0.714
# 19     1          81       0.0695  107.936              4    0.580
# 20     1          81       0.0695  107.936              4    0.580
# 21     1          81       0.0695  107.936              4    0.580
# 22     1          81       0.0695  107.936              4    0.580
# 23     1          81       0.0695  107.936              4    0.580
# 24     1          81       0.0695  107.936              4    0.580
# 25     1          81       0.0695  107.936              4    0.580
# 26     1          81       0.0695  107.936              4    0.580
# 27     1          81       0.0695  107.936              4    0.580
# 28     1          81       0.0695  107.936              4    0.580
# 29     1          81       0.0695  107.936              4    0.580
# 30     1          79       0.0486  140.975              4    0.599
# 31     1          79       0.0486  140.975              4    0.599
# 32     1          79       0.0486  140.975              4    0.599
# 33     1          79       0.0486  140.975              4    0.599
# 34     1          79       0.0486  140.975              4    0.599
# 35     1          79       0.0486  140.975              4    0.599
# 36     1          79       0.0486  140.975              4    0.599
# 37     1          79       0.0486  140.975              4    0.599
# 38     1          79       0.0486  140.975              4    0.599
# 39     1          79       0.0486  140.975              4    0.599
#
# [40 rows x 23 columns]

# %%
bb_song2 = bb_song.drop_duplicates(subset = ["Artists", "Name"])
len(bb_song2)

#Billboard Top Hits had a lot of duplicate songs since it was the weekly top ranks and many songs stay on top charts 
#for multiple weeks -> dropped all duplicates except for the most recent one since that one has the actual peak position
#Song Atttributes data was also missing a lot of songs data or we were unable to cross match due to differences in 
#song title format and the artists for the song listed. Song attributes only had the singular artists and the 
#song names said (feat. xyz) while Billboard Top 100 sometimes had more than one artist listed, or had them acknowledged
#in separate 'Feature' column, typically didnt have (feat. xyz) in title
# Out:
# 1350

# %%
bb_song2.groupby('Year').count()
# Out:
#       Artists  Name  Weekly.rank  Peak.position  Weeks.on.chart  Unnamed: 0  \
# Year
# 2010      215   215          215            166             166         215
# 2011      189   189          189            150             150         189
# 2012      170   170          170            146             146         170
# 2013      166   166          166            131             131         166
# 2014      124   124          124            109             109         124
# 2015      114   114          114             88              88         114
# 2016      115   115          115            100             100         115
# 2017      114   114          114             86              86         114
# 2018      115   115          115             78              78         115
# 2019       28    28           28             25              25          28
#
#       Acousticness  Album  Artist  Danceability  ...  Explicit  \
# Year                                             ...
# 2010           215    215     215           215  ...       215
# 2011           189    189     189           189  ...       189
# 2012           170    170     170           170  ...       170
# 2013           166    166     166           166  ...       166
# 2014           124    124     124           124  ...       124
# 2015           114    114     114           114  ...       114
# 2016           115    115     115           115  ...       115
# 2017           114    114     114           114  ...       114
# 2018           115    115     115           115  ...       115
# 2019            28     28      28            28  ...        28
#
#       Instrumentalness  Liveness  Loudness  Mode  Popularity  Speechiness  \
# Year
# 2010               215       215       215   215         215          215
# 2011               189       189       189   189         189          189
# 2012               170       170       170   170         170          170
# 2013               166       166       166   166         166          166
# 2014               124       124       124   124         124          124
# 2015               114       114       114   114         114          114
# 2016               115       115       115   115         115          115
# 2017               114       114       114   114         114          114
# 2018               115       115       115   115         115          115
# 2019                28        28        28    28          28           28
#
#       Tempo  TimeSignature  Valence
# Year
# 2010    215            215      215
# 2011    189            189      189
# 2012    170            170      170
# 2013    166            166      166
# 2014    124            124      124
# 2015    114            114      114
# 2016    115            115      115
# 2017    114            114      114
# 2018    115            115      115
# 2019     28             28       28
#
# [10 rows x 22 columns]

# %%
bb_song3 = bb_song2[bb_song2["Peak.position"].notna()]
len(bb_song3)
# Out:
# 1079

# %%
bb_song4 = bb_song3.drop(columns = ["Weekly.rank", "Unnamed: 0", "Album", "Artist"])
bb_song4.head()
# Out:
#                 Artists                    Name  Peak.position  \
# 0        Jonas Brothers                  Sucker            1.0
# 17         Taylor Swift   You Need To Calm Down            2.0
# 19  Panic! At The Disco  Hey Look Ma, I Made It           24.0
# 30            Lee Brice                   Rumor           25.0
# 46  Panic! At The Disco              High Hopes            4.0
#
#     Weeks.on.chart  Year  Acousticness  Danceability  Duration  Energy  \
# 0             17.0  2019       0.04270         0.842    181027   0.734
# 17             2.0  2019       0.00929         0.771    171360   0.671
# 19            11.0  2019       0.01370         0.577    169667   0.833
# 30            16.0  2019       0.74900         0.655    198440   0.560
# 46            47.0  2019       0.19300         0.579    190947   0.904
#
#     Explicit  Instrumentalness  Liveness  Loudness  Mode  Popularity  \
# 0      False               0.0    0.1060    -5.065     0          81
# 17     False               0.0    0.0637    -5.617     1          89
# 19     False               0.0    0.1210    -3.337     1          81
# 30     False               0.0    0.1150    -6.857     1          79
# 46     False               0.0    0.0640    -2.729     1          87
#
#     Speechiness    Tempo  TimeSignature  Valence
# 0        0.0588  137.958              4    0.952
# 17       0.0553   85.026              4    0.714
# 19       0.0695  107.936              4    0.580
# 30       0.0486  140.975              4    0.599
# 46       0.0618   82.014              4    0.681

# %%
bb_grammy_song = pd.merge(bb_song4, grammy, left_on = ["Artists", "Name"],
                         right_on = ["Artist", "Name"], how = "left")
bb_grammy_song.head()
# Out:
#                Artists                    Name  Peak.position  Weeks.on.chart  \
# 0       Jonas Brothers                  Sucker            1.0            17.0
# 1         Taylor Swift   You Need To Calm Down            2.0             2.0
# 2  Panic! At The Disco  Hey Look Ma, I Made It           24.0            11.0
# 3            Lee Brice                   Rumor           25.0            16.0
# 4  Panic! At The Disco              High Hopes            4.0            47.0
#
#    Year  Acousticness  Danceability  Duration  Energy  Explicit  ...  \
# 0  2019       0.04270         0.842    181027   0.734     False  ...
# 1  2019       0.00929         0.771    171360   0.671     False  ...
# 2  2019       0.01370         0.577    169667   0.833     False  ...
# 3  2019       0.74900         0.655    198440   0.560     False  ...
# 4  2019       0.19300         0.579    190947   0.904     False  ...
#
#    Speechiness    Tempo  TimeSignature  Valence  Unnamed: 0   X  GrammyAward  \
# 0       0.0588  137.958              4    0.952         NaN NaN          NaN
# 1       0.0553   85.026              4    0.714         NaN NaN          NaN
# 2       0.0695  107.936              4    0.580         NaN NaN          NaN
# 3       0.0486  140.975              4    0.599         NaN NaN          NaN
# 4       0.0618   82.014              4    0.681         NaN NaN          NaN
#
#    GrammyYear  Genre  Artist
# 0         NaN    NaN     NaN
# 1         NaN    NaN     NaN
# 2         NaN    NaN     NaN
# 3         NaN    NaN     NaN
# 4         NaN    NaN     NaN
#
# [5 rows x 25 columns]

# %%
g_bool = bb_grammy_song["X"].notnull().astype('int')
bb_grammy_song["Grammy"] = g_bool
bb_grammy_song2 = bb_grammy_song.drop_duplicates(subset = ["Artists", "Name"])
bb_grammy_song3 = bb_grammy_song2.drop(columns = ["Unnamed: 0", "X", "GrammyAward", "GrammyYear", "Genre", "Artist"])
bb_grammy_song3.head()
# Out:
#                Artists                    Name  Peak.position  Weeks.on.chart  \
# 0       Jonas Brothers                  Sucker            1.0            17.0
# 1         Taylor Swift   You Need To Calm Down            2.0             2.0
# 2  Panic! At The Disco  Hey Look Ma, I Made It           24.0            11.0
# 3            Lee Brice                   Rumor           25.0            16.0
# 4  Panic! At The Disco              High Hopes            4.0            47.0
#
#    Year  Acousticness  Danceability  Duration  Energy  Explicit  \
# 0  2019       0.04270         0.842    181027   0.734     False
# 1  2019       0.00929         0.771    171360   0.671     False
# 2  2019       0.01370         0.577    169667   0.833     False
# 3  2019       0.74900         0.655    198440   0.560     False
# 4  2019       0.19300         0.579    190947   0.904     False
#
#    Instrumentalness  Liveness  Loudness  Mode  Popularity  Speechiness  \
# 0               0.0    0.1060    -5.065     0          81       0.0588
# 1               0.0    0.0637    -5.617     1          89       0.0553
# 2               0.0    0.1210    -3.337     1          81       0.0695
# 3               0.0    0.1150    -6.857     1          79       0.0486
# 4               0.0    0.0640    -2.729     1          87       0.0618
#
#      Tempo  TimeSignature  Valence  Grammy
# 0  137.958              4    0.952       0
# 1   85.026              4    0.714       0
# 2  107.936              4    0.580       0
# 3  140.975              4    0.599       0
# 4   82.014              4    0.681       0

# %%
#final data
music_without_nom = bb_grammy_song3.rename(columns={"Peak.position":"Peak_position", 
                                       "Weeks.on.chart":"Weeks_on_chart"})
music_without_nom['Explicit'] = music_without_nom['Explicit'].astype(int)

# %%
grammy_noms_over10 = grammy_noms[grammy_noms['year'] >= 2010]
grammy_noms_over10['Name'] = grammy_noms_over10['nominee'].str.partition('(')[0]
grammy_noms_over10['Nominated'] = 1
grammy_noms_final = grammy_noms_over10[['Name', 'Nominated']]

# %%
updated_mus = pd.merge(music_without_nom, grammy_noms_final, left_on = 'Name', right_on = 'Name', how = 'left')
updated_mus['Nominated'] = updated_mus['Nominated'].fillna(0)
grammy_inds = updated_mus[updated_mus['Grammy'] == 1].index
updated_mus.iloc[grammy_inds,-1] = 1

# %%
music = updated_mus
music.head()
# Out:
#                Artists                    Name  Peak_position  Weeks_on_chart  \
# 0       Jonas Brothers                  Sucker            1.0            17.0
# 1         Taylor Swift   You Need To Calm Down            2.0             2.0
# 2  Panic! At The Disco  Hey Look Ma, I Made It           24.0            11.0
# 3            Lee Brice                   Rumor           25.0            16.0
# 4  Panic! At The Disco              High Hopes            4.0            47.0
#
#    Year  Acousticness  Danceability  Duration  Energy  Explicit  ...  \
# 0  2019       0.04270         0.842    181027   0.734         0  ...
# 1  2019       0.00929         0.771    171360   0.671         0  ...
# 2  2019       0.01370         0.577    169667   0.833         0  ...
# 3  2019       0.74900         0.655    198440   0.560         0  ...
# 4  2019       0.19300         0.579    190947   0.904         0  ...
#
#    Liveness  Loudness  Mode  Popularity  Speechiness    Tempo  TimeSignature  \
# 0    0.1060    -5.065     0          81       0.0588  137.958              4
# 1    0.0637    -5.617     1          89       0.0553   85.026              4
# 2    0.1210    -3.337     1          81       0.0695  107.936              4
# 3    0.1150    -6.857     1          79       0.0486  140.975              4
# 4    0.0640    -2.729     1          87       0.0618   82.014              4
#
#    Valence  Grammy  Nominated
# 0    0.952       0        0.0
# 1    0.714       0        0.0
# 2    0.580       0        0.0
# 3    0.599       0        0.0
# 4    0.681       0        0.0
#
# [5 rows x 21 columns]

# %%
train = music[music["Year"] <= 2016]
test = music[music["Year"]>= 2017]

# %%
#regression -- predict peak position 
r_ytr = train["Peak_position"]
r_xtr = train.drop(columns = ["Peak_position"])
r_yte = test["Peak_position"]
r_xte = test.drop(columns = ["Peak_position"])

#classification -- predict whether or not the song will be nominated for a Grammy 
c_ytr = train["Nominated"]
c_xtr = train.drop(columns = ["Nominated"])
c_yte = test["Nominated"]
c_xte = test.drop(columns = ["Nominated"])

# %%
music.to_csv('music_data.csv', index=False)

# %% [markdown]
# # Linear/Logistic Regression

# %%
music = pd.read_csv('music_data.csv')

train = music[music["Year"] <= 2016]
test = music[music["Year"] >= 2017]

#regression -- predict peak position 
r_ytr = train["Peak_position"]
r_xtr = train.drop(columns = ["Peak_position"])
r_yte = test["Peak_position"]
r_xte = test.drop(columns = ["Peak_position"])

#classification -- predict whether or not the song will win a grammy 
c_ytr = train["Nominated"]
c_xtr = train.drop(columns = ["Nominated"])
c_yte = test["Nominated"]
c_xte = test.drop(columns = ["Nominated"])

# %% [markdown]
# ## Linear Regression

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def VIF(df, col):
    vals = sm.add_constant(df[col]).values
    num_col = len(col) + 1
    vif = [variance_inflation_factor(vals, i) for i in range(num_col)]
    return pd.Series(vif[1:], index = col)

# %%
linreg1 = smf.ols(formula = 'Peak_position ~ Weeks_on_chart + Year + Acousticness + Danceability + Duration + Energy + Explicit + Instrumentalness + Liveness + Loudness + Mode + Popularity + Speechiness + Tempo + TimeSignature + Valence + Grammy + Nominated', data = train).fit()
print(linreg1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Peak_position   R-squared:                       0.505
# Model:                            OLS   Adj. R-squared:                  0.495
# Method:                 Least Squares   F-statistic:                     49.74
# Date:                Fri, 17 Dec 2021   Prob (F-statistic):          1.66e-120
# Time:                        20:15:00   Log-Likelihood:                -3914.3
# No. Observations:                 896   AIC:                             7867.
# Df Residuals:                     877   BIC:                             7958.
# Df Model:                          18
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept        -1081.3694    706.937     -1.530      0.126   -2468.856     306.117
# Weeks_on_chart      -1.7346      0.063    -27.505      0.000      -1.858      -1.611
# Year                 0.5734      0.351      1.633      0.103      -0.116       1.262
# Acousticness         1.9853      3.949      0.503      0.615      -5.766       9.737
# Danceability        -3.6450      6.043     -0.603      0.547     -15.506       8.216
# Duration         -1.543e-06   1.64e-05     -0.094      0.925   -3.37e-05    3.06e-05
# Energy              11.7830      7.163      1.645      0.100      -2.275      25.841
# Explicit            -3.0456      1.950     -1.562      0.119      -6.873       0.782
# Instrumentalness     6.5873     11.018      0.598      0.550     -15.038      28.213
# Liveness            -7.9056      4.483     -1.764      0.078     -16.704       0.893
# Loudness            -0.2504      0.443     -0.565      0.572      -1.121       0.620
# Mode                 6.1532      1.503      4.094      0.000       3.203       9.103
# Popularity          -0.0828      0.031     -2.663      0.008      -0.144      -0.022
# Speechiness          3.5542      8.366      0.425      0.671     -12.865      19.974
# Tempo               -0.0383      0.024     -1.602      0.109      -0.085       0.009
# TimeSignature       -0.2649      3.457     -0.077      0.939      -7.049       6.519
# Valence             -2.4385      3.787     -0.644      0.520      -9.872       4.995
# Grammy              -5.1565      6.368     -0.810      0.418     -17.656       7.343
# Nominated            0.1080      4.457      0.024      0.981      -8.640       8.856
# ==============================================================================
# Omnibus:                        1.751   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.417   Jarque-Bera (JB):                1.820
# Skew:                          -0.102   Prob(JB):                        0.402
# Kurtosis:                       2.914   Cond. No.                     2.58e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.58e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
## removed 'Nominated' (p-value of .981)
linreg2 = smf.ols(formula = 'Peak_position ~ Weeks_on_chart + Year + Acousticness + Danceability + Duration + Energy + Explicit + Instrumentalness + Liveness + Loudness + Mode + Popularity + Speechiness + Tempo + TimeSignature + Valence + Grammy', data = train).fit()
print(linreg2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Peak_position   R-squared:                       0.505
# Model:                            OLS   Adj. R-squared:                  0.496
# Method:                 Least Squares   F-statistic:                     52.73
# Date:                Fri, 17 Dec 2021   Prob (F-statistic):          2.25e-121
# Time:                        20:15:01   Log-Likelihood:                -3914.3
# No. Observations:                 896   AIC:                             7865.
# Df Residuals:                     878   BIC:                             7951.
# Df Model:                          17
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept        -1081.8843    706.216     -1.532      0.126   -2467.952     304.184
# Weeks_on_chart      -1.7345      0.063    -27.699      0.000      -1.857      -1.612
# Year                 0.5737      0.351      1.636      0.102      -0.115       1.262
# Acousticness         1.9864      3.947      0.503      0.615      -5.760       9.733
# Danceability        -3.6528      6.031     -0.606      0.545     -15.490       8.185
# Duration         -1.557e-06   1.64e-05     -0.095      0.924   -3.37e-05    3.06e-05
# Energy              11.7757      7.152      1.646      0.100      -2.262      25.813
# Explicit            -3.0455      1.949     -1.562      0.119      -6.871       0.780
# Instrumentalness     6.5823     11.010      0.598      0.550     -15.027      28.192
# Liveness            -7.8976      4.468     -1.768      0.077     -16.667       0.872
# Loudness            -0.2504      0.443     -0.565      0.572      -1.120       0.619
# Mode                 6.1507      1.499      4.104      0.000       3.209       9.092
# Popularity          -0.0828      0.031     -2.665      0.008      -0.144      -0.022
# Speechiness          3.5610      8.356      0.426      0.670     -12.840      19.962
# Tempo               -0.0384      0.024     -1.604      0.109      -0.085       0.009
# TimeSignature       -0.2686      3.451     -0.078      0.938      -7.042       6.505
# Valence             -2.4388      3.785     -0.644      0.520      -9.868       4.990
# Grammy              -5.0523      4.695     -1.076      0.282     -14.267       4.162
# ==============================================================================
# Omnibus:                        1.747   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.417   Jarque-Bera (JB):                1.817
# Skew:                          -0.102   Prob(JB):                        0.403
# Kurtosis:                       2.914   Cond. No.                     2.58e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.58e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
## removed 'TimeSignature' (p-value of .938)
linreg2 = smf.ols(formula = 'Peak_position ~ Weeks_on_chart + Year + Acousticness + Danceability + Duration + Energy + Explicit + Instrumentalness + Liveness + Loudness + Mode + Popularity + Speechiness + Tempo + Valence + Grammy', data = train).fit()
print(linreg2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Peak_position   R-squared:                       0.505
# Model:                            OLS   Adj. R-squared:                  0.496
# Method:                 Least Squares   F-statistic:                     56.08
# Date:                Fri, 17 Dec 2021   Prob (F-statistic):          2.97e-122
# Time:                        20:15:01   Log-Likelihood:                -3914.3
# No. Observations:                 896   AIC:                             7863.
# Df Residuals:                     879   BIC:                             7944.
# Df Model:                          16
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept        -1085.5064    704.282     -1.541      0.124   -2467.777     296.764
# Weeks_on_chart      -1.7347      0.063    -27.750      0.000      -1.857      -1.612
# Year                 0.5750      0.350      1.642      0.101      -0.112       1.262
# Acousticness         2.0002      3.941      0.508      0.612      -5.734       9.734
# Danceability        -3.6750      6.021     -0.610      0.542     -15.493       8.142
# Duration         -1.572e-06   1.64e-05     -0.096      0.923   -3.37e-05    3.05e-05
# Energy              11.7108      7.100      1.649      0.099      -2.223      25.645
# Explicit            -3.0483      1.948     -1.565      0.118      -6.871       0.774
# Instrumentalness     6.5753     11.004      0.598      0.550     -15.021      28.172
# Liveness            -7.8714      4.453     -1.768      0.077     -16.611       0.868
# Loudness            -0.2492      0.443     -0.563      0.574      -1.118       0.619
# Mode                 6.1463      1.497      4.106      0.000       3.209       9.084
# Popularity          -0.0829      0.031     -2.670      0.008      -0.144      -0.022
# Speechiness          3.5193      8.335      0.422      0.673     -12.839      19.877
# Tempo               -0.0382      0.024     -1.606      0.109      -0.085       0.008
# Valence             -2.4478      3.781     -0.647      0.518      -9.869       4.974
# Grammy              -5.0533      4.692     -1.077      0.282     -14.263       4.156
# ==============================================================================
# Omnibus:                        1.760   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.415   Jarque-Bera (JB):                1.829
# Skew:                          -0.102   Prob(JB):                        0.401
# Kurtosis:                       2.915   Cond. No.                     2.57e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.57e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
## removed 'Duration' (p-value of .923)
linreg3 = smf.ols(formula = 'Peak_position ~ Weeks_on_chart + Year + Acousticness + Danceability + Energy + Explicit + Instrumentalness + Liveness + Loudness + Mode + Popularity + Speechiness + Tempo + Valence + Grammy', data = train).fit()
print(linreg3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Peak_position   R-squared:                       0.505
# Model:                            OLS   Adj. R-squared:                  0.497
# Method:                 Least Squares   F-statistic:                     59.89
# Date:                Fri, 17 Dec 2021   Prob (F-statistic):          3.78e-123
# Time:                        20:15:02   Log-Likelihood:                -3914.3
# No. Observations:                 896   AIC:                             7861.
# Df Residuals:                     880   BIC:                             7937.
# Df Model:                          15
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept        -1090.5913    701.896     -1.554      0.121   -2468.178     286.995
# Weeks_on_chart      -1.7347      0.062    -27.767      0.000      -1.857      -1.612
# Year                 0.5773      0.349      1.654      0.099      -0.108       1.262
# Acousticness         2.0084      3.937      0.510      0.610      -5.720       9.736
# Danceability        -3.6535      6.014     -0.608      0.544     -15.456       8.149
# Energy              11.7030      7.095      1.649      0.099      -2.222      25.628
# Explicit            -3.0616      1.942     -1.577      0.115      -6.873       0.749
# Instrumentalness     6.6049     10.993      0.601      0.548     -14.971      28.181
# Liveness            -7.8630      4.450     -1.767      0.078     -16.596       0.870
# Loudness            -0.2460      0.441     -0.558      0.577      -1.112       0.620
# Mode                 6.1483      1.496      4.110      0.000       3.213       9.084
# Popularity          -0.0829      0.031     -2.674      0.008      -0.144      -0.022
# Speechiness          3.4465      8.295      0.415      0.678     -12.835      19.728
# Tempo               -0.0381      0.024     -1.605      0.109      -0.085       0.008
# Valence             -2.3757      3.704     -0.641      0.521      -9.645       4.894
# Grammy              -5.0755      4.684     -1.084      0.279     -14.269       4.117
# ==============================================================================
# Omnibus:                        1.790   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.409   Jarque-Bera (JB):                1.859
# Skew:                          -0.103   Prob(JB):                        0.395
# Kurtosis:                       2.914   Cond. No.                     2.20e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.2e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
## removed 'Speechiness' (p-value of .678)
linreg4 = smf.ols(formula = 'Peak_position ~ Weeks_on_chart + Year + Acousticness + Danceability + Energy + Explicit + Instrumentalness + Liveness + Loudness + Mode + Popularity + Tempo + Valence + Grammy', data = train).fit()
print(linreg4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Peak_position   R-squared:                       0.505
# Model:                            OLS   Adj. R-squared:                  0.497
# Method:                 Least Squares   F-statistic:                     64.22
# Date:                Fri, 17 Dec 2021   Prob (F-statistic):          5.04e-124
# Time:                        20:15:02   Log-Likelihood:                -3914.4
# No. Observations:                 896   AIC:                             7859.
# Df Residuals:                     881   BIC:                             7931.
# Df Model:                          14
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept        -1090.2009    701.566     -1.554      0.121   -2467.137     286.735
# Weeks_on_chart      -1.7348      0.062    -27.781      0.000      -1.857      -1.612
# Year                 0.5769      0.349      1.654      0.099      -0.108       1.262
# Acousticness         2.1195      3.927      0.540      0.589      -5.587       9.826
# Danceability        -3.5933      6.009     -0.598      0.550     -15.387       8.200
# Energy              11.9938      7.057      1.699      0.090      -1.857      25.845
# Explicit            -2.6754      1.704     -1.570      0.117      -6.020       0.669
# Instrumentalness     6.4155     10.979      0.584      0.559     -15.132      27.963
# Liveness            -7.6908      4.428     -1.737      0.083     -16.382       1.000
# Loudness            -0.2708      0.437     -0.620      0.535      -1.128       0.586
# Mode                 6.0992      1.490      4.092      0.000       3.174       9.024
# Popularity          -0.0826      0.031     -2.666      0.008      -0.143      -0.022
# Tempo               -0.0373      0.024     -1.577      0.115      -0.084       0.009
# Valence             -2.3724      3.702     -0.641      0.522      -9.639       4.894
# Grammy              -5.0833      4.682     -1.086      0.278     -14.272       4.105
# ==============================================================================
# Omnibus:                        1.786   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.409   Jarque-Bera (JB):                1.853
# Skew:                          -0.103   Prob(JB):                        0.396
# Kurtosis:                       2.917   Cond. No.                     2.20e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.2e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
## removed 'Acousticness' (p-value of .589)
linreg5 = smf.ols(formula = 'Peak_position ~ Weeks_on_chart + Year + Danceability + Energy + Explicit + Instrumentalness + Liveness + Loudness + Mode + Popularity + Tempo + Valence + Grammy', data = train).fit()
print(linreg5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Peak_position   R-squared:                       0.505
# Model:                            OLS   Adj. R-squared:                  0.498
# Method:                 Least Squares   F-statistic:                     69.19
# Date:                Fri, 17 Dec 2021   Prob (F-statistic):          6.85e-125
# Time:                        20:15:03   Log-Likelihood:                -3914.6
# No. Observations:                 896   AIC:                             7857.
# Df Residuals:                     882   BIC:                             7924.
# Df Model:                          13
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept        -1089.2500    701.282     -1.553      0.121   -2465.626     287.126
# Weeks_on_chart      -1.7358      0.062    -27.821      0.000      -1.858      -1.613
# Year                 0.5774      0.349      1.656      0.098      -0.107       1.262
# Danceability        -4.0626      5.943     -0.684      0.494     -15.727       7.602
# Energy              10.3888      6.398      1.624      0.105      -2.168      22.946
# Explicit            -2.7096      1.702     -1.592      0.112      -6.050       0.631
# Instrumentalness     6.3976     10.974      0.583      0.560     -15.141      27.936
# Liveness            -7.6743      4.426     -1.734      0.083     -16.361       1.013
# Loudness            -0.2641      0.436     -0.605      0.545      -1.121       0.592
# Mode                 6.1393      1.488      4.126      0.000       3.219       9.060
# Popularity          -0.0837      0.031     -2.706      0.007      -0.144      -0.023
# Tempo               -0.0390      0.023     -1.665      0.096      -0.085       0.007
# Valence             -2.1015      3.667     -0.573      0.567      -9.298       5.095
# Grammy              -4.8825      4.665     -1.047      0.296     -14.038       4.273
# ==============================================================================
# Omnibus:                        1.786   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.409   Jarque-Bera (JB):                1.846
# Skew:                          -0.105   Prob(JB):                        0.397
# Kurtosis:                       2.926   Cond. No.                     2.20e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.2e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
## removed 'Valence' (p-value of .567)
linreg6 = smf.ols(formula = 'Peak_position ~ Weeks_on_chart + Year + Danceability + Energy + Explicit + Instrumentalness + Liveness + Loudness + Mode + Popularity + Tempo + Grammy', data = train).fit()
print(linreg6.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Peak_position   R-squared:                       0.505
# Model:                            OLS   Adj. R-squared:                  0.498
# Method:                 Least Squares   F-statistic:                     74.98
# Date:                Fri, 17 Dec 2021   Prob (F-statistic):          9.10e-126
# Time:                        20:15:03   Log-Likelihood:                -3914.7
# No. Observations:                 896   AIC:                             7855.
# Df Residuals:                     883   BIC:                             7918.
# Df Model:                          12
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept        -1093.1319    700.983     -1.559      0.119   -2468.919     282.655
# Weeks_on_chart      -1.7364      0.062    -27.845      0.000      -1.859      -1.614
# Year                 0.5798      0.349      1.663      0.097      -0.104       1.264
# Danceability        -5.4479      5.428     -1.004      0.316     -16.100       5.205
# Energy               9.1704      6.032      1.520      0.129      -2.668      21.009
# Explicit            -2.5149      1.667     -1.508      0.132      -5.787       0.757
# Instrumentalness     6.3935     10.970      0.583      0.560     -15.137      27.924
# Liveness            -7.7281      4.424     -1.747      0.081     -16.410       0.954
# Loudness            -0.2547      0.436     -0.584      0.559      -1.110       0.601
# Mode                 6.1369      1.487      4.126      0.000       3.218       9.056
# Popularity          -0.0841      0.031     -2.720      0.007      -0.145      -0.023
# Tempo               -0.0403      0.023     -1.728      0.084      -0.086       0.005
# Grammy              -4.8103      4.662     -1.032      0.302     -13.959       4.339
# ==============================================================================
# Omnibus:                        1.710   Durbin-Watson:                   1.937
# Prob(Omnibus):                  0.425   Jarque-Bera (JB):                1.754
# Skew:                          -0.105   Prob(JB):                        0.416
# Kurtosis:                       2.943   Cond. No.                     2.20e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.2e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
## removed 'Instrumentalness' (p-value of .560)
linreg7 = smf.ols(formula = 'Peak_position ~ Weeks_on_chart + Year + Danceability + Energy + Explicit + Liveness + Loudness + Mode + Popularity + Tempo + Grammy', data = train).fit()
print(linreg7.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Peak_position   R-squared:                       0.505
# Model:                            OLS   Adj. R-squared:                  0.498
# Method:                 Least Squares   F-statistic:                     81.83
# Date:                Fri, 17 Dec 2021   Prob (F-statistic):          1.16e-126
# Time:                        20:15:04   Log-Likelihood:                -3914.9
# No. Observations:                 896   AIC:                             7854.
# Df Residuals:                     884   BIC:                             7911.
# Df Model:                          11
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept      -1077.5689    700.212     -1.539      0.124   -2451.841     296.704
# Weeks_on_chart    -1.7342      0.062    -27.871      0.000      -1.856      -1.612
# Year               0.5719      0.348      1.642      0.101      -0.112       1.255
# Danceability      -5.5062      5.425     -1.015      0.310     -16.153       5.141
# Energy             9.3730      6.020      1.557      0.120      -2.442      21.188
# Explicit          -2.5525      1.665     -1.533      0.126      -5.821       0.716
# Liveness          -7.8474      4.417     -1.777      0.076     -16.517       0.822
# Loudness          -0.2953      0.430     -0.686      0.493      -1.140       0.549
# Mode               6.1423      1.487      4.131      0.000       3.224       9.060
# Popularity        -0.0843      0.031     -2.729      0.006      -0.145      -0.024
# Tempo             -0.0405      0.023     -1.740      0.082      -0.086       0.005
# Grammy            -4.8754      4.658     -1.047      0.296     -14.018       4.268
# ==============================================================================
# Omnibus:                        1.399   Durbin-Watson:                   1.938
# Prob(Omnibus):                  0.497   Jarque-Bera (JB):                1.369
# Skew:                          -0.096   Prob(JB):                        0.504
# Kurtosis:                       3.000   Cond. No.                     2.20e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.2e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
## removed 'Loudness' (p-value of .493)
linreg8 = smf.ols(formula = 'Peak_position ~ Weeks_on_chart + Year + Danceability + Energy +\
                  Explicit + Liveness + Mode + Popularity + Tempo + Grammy', data = train).fit()
print(linreg8.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Peak_position   R-squared:                       0.504
# Model:                            OLS   Adj. R-squared:                  0.499
# Method:                 Least Squares   F-statistic:                     90.02
# Date:                Fri, 17 Dec 2021   Prob (F-statistic):          1.51e-127
# Time:                        20:15:04   Log-Likelihood:                -3915.1
# No. Observations:                 896   AIC:                             7852.
# Df Residuals:                     885   BIC:                             7905.
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept      -1132.2709    695.454     -1.628      0.104   -2497.203     232.661
# Weeks_on_chart    -1.7357      0.062    -27.918      0.000      -1.858      -1.614
# Year               0.6010      0.346      1.739      0.082      -0.077       1.279
# Danceability      -5.7279      5.413     -1.058      0.290     -16.353       4.897
# Energy             6.5528      4.398      1.490      0.137      -2.079      15.185
# Explicit          -2.5239      1.664     -1.516      0.130      -5.790       0.743
# Liveness          -7.5233      4.391     -1.714      0.087     -16.140       1.094
# Mode               6.2004      1.484      4.178      0.000       3.288       9.113
# Popularity        -0.0848      0.031     -2.746      0.006      -0.145      -0.024
# Tempo             -0.0411      0.023     -1.766      0.078      -0.087       0.005
# Grammy            -4.8779      4.657     -1.047      0.295     -14.018       4.262
# ==============================================================================
# Omnibus:                        1.448   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.485   Jarque-Bera (JB):                1.394
# Skew:                          -0.096   Prob(JB):                        0.498
# Kurtosis:                       3.015   Cond. No.                     2.18e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.18e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
col_names = ['Weeks_on_chart', 'Year', 'Danceability', 'Energy', 'Explicit', 
             'Liveness', 'Mode', 'Popularity', 'Tempo', 'Grammy']
VIF(train, col_names)
# Out:
# Weeks_on_chart    1.061279
# Year              1.130403
# Danceability      1.158319
# Energy            1.124299
# Explicit          1.183439
# Liveness          1.056428
# Mode              1.051193
# Popularity        1.094194
# Tempo             1.072517
# Grammy            1.033793
# dtype: float64

# %%
def rmse(model, df_test, dependent_var):
    y_test = df_test[dependent_var]
    y_pred = model.predict(df_test)
    se = (y_test - y_pred) ** 2
    mse = np.mean(se)
    return np.sqrt(mse)

# %%
linreg8_rmse = rmse(linreg8, r_xte, 'Weeks_on_chart')
print('RMSE on testing: ', linreg8_rmse)
# Out:
# RMSE on testing:  46.33864520971443

# %% [markdown]
# ## Logistic Regression

# %%
logreg1 = smf.logit(formula = 'Nominated ~ Peak_position + Weeks_on_chart + Year + Acousticness + Danceability + Duration + Energy + Explicit + Instrumentalness + Liveness + Loudness + Mode + Popularity + Speechiness + Tempo + TimeSignature + Valence', data=train).fit()
print(logreg1.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.152239
#          Iterations 11
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Nominated   No. Observations:                  896
# Model:                          Logit   Df Residuals:                      878
# Method:                           MLE   Df Model:                           17
# Date:                Fri, 17 Dec 2021   Pseudo R-squ.:                  0.1327
# Time:                        20:15:13   Log-Likelihood:                -136.41
# converged:                       True   LL-Null:                       -157.28
# Covariance Type:            nonrobust   LLR p-value:                 0.0007312
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept         -269.4558    190.872     -1.412      0.158    -643.558     104.646
# Peak_position       -0.0120      0.010     -1.225      0.221      -0.031       0.007
# Weeks_on_chart       0.0342      0.019      1.820      0.069      -0.003       0.071
# Year                 0.1326      0.095      1.399      0.162      -0.053       0.318
# Acousticness         1.4306      0.926      1.545      0.122      -0.384       3.245
# Danceability        -0.1877      1.553     -0.121      0.904      -3.232       2.857
# Duration          1.188e-06   3.72e-06      0.320      0.749   -6.09e-06    8.47e-06
# Energy              -1.2839      1.934     -0.664      0.507      -5.075       2.507
# Explicit            -0.2869      0.526     -0.546      0.585      -1.317       0.743
# Instrumentalness    -7.9688     14.495     -0.550      0.582     -36.378      20.440
# Liveness             0.8272      1.188      0.696      0.486      -1.501       3.155
# Loudness             0.0108      0.114      0.095      0.924      -0.212       0.234
# Mode                -0.7886      0.366     -2.152      0.031      -1.507      -0.070
# Popularity          -0.0033      0.008     -0.412      0.680      -0.019       0.012
# Speechiness          0.5727      1.890      0.303      0.762      -3.132       4.278
# Tempo                0.0120      0.006      1.892      0.058      -0.000       0.024
# TimeSignature       -0.2727      0.725     -0.376      0.707      -1.693       1.148
# Valence             -0.6759      1.068     -0.633      0.527      -2.768       1.417
# ====================================================================================

# %%
## removed 'Loudness' (p-value of .924)
logreg2 = smf.logit(formula = 'Nominated ~ Peak_position + Weeks_on_chart + Year + Acousticness + Danceability + Duration + Energy + Explicit + Instrumentalness + Liveness + Mode + Popularity + Speechiness + Tempo + TimeSignature + Valence', data=train).fit()
print(logreg2.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.152244
#          Iterations 11
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Nominated   No. Observations:                  896
# Model:                          Logit   Df Residuals:                      879
# Method:                           MLE   Df Model:                           16
# Date:                Fri, 17 Dec 2021   Pseudo R-squ.:                  0.1327
# Time:                        20:15:13   Log-Likelihood:                -136.41
# converged:                       True   LL-Null:                       -157.28
# Covariance Type:            nonrobust   LLR p-value:                 0.0004328
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept         -267.7553    190.067     -1.409      0.159    -640.281     104.770
# Peak_position       -0.0120      0.010     -1.226      0.220      -0.031       0.007
# Weeks_on_chart       0.0343      0.019      1.823      0.068      -0.003       0.071
# Year                 0.1317      0.094      1.397      0.163      -0.053       0.317
# Acousticness         1.4333      0.925      1.549      0.121      -0.380       3.247
# Danceability        -0.1681      1.539     -0.109      0.913      -3.185       2.849
# Duration          1.161e-06   3.69e-06      0.314      0.753   -6.08e-06     8.4e-06
# Energy              -1.1666      1.492     -0.782      0.434      -4.091       1.758
# Explicit            -0.2851      0.526     -0.542      0.588      -1.315       0.745
# Instrumentalness    -8.1500     14.712     -0.554      0.580     -36.984      20.684
# Liveness             0.8134      1.179      0.690      0.490      -1.497       3.124
# Mode                -0.7914      0.365     -2.166      0.030      -1.508      -0.075
# Popularity          -0.0032      0.008     -0.409      0.683      -0.019       0.012
# Speechiness          0.5495      1.875      0.293      0.770      -3.126       4.225
# Tempo                0.0121      0.006      1.904      0.057      -0.000       0.024
# TimeSignature       -0.2775      0.723     -0.384      0.701      -1.695       1.140
# Valence             -0.6826      1.065     -0.641      0.522      -2.770       1.405
# ====================================================================================

# %%
## removed 'Danceability' (p-value of .913)
logreg3 = smf.logit(formula = 'Nominated ~ Peak_position + Weeks_on_chart + Year + Acousticness + Duration + Energy + Explicit + Instrumentalness + Liveness + Mode + Popularity + Speechiness + Tempo + TimeSignature + Valence', data=train).fit()
print(logreg3.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.152251
#          Iterations 11
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Nominated   No. Observations:                  896
# Model:                          Logit   Df Residuals:                      880
# Method:                           MLE   Df Model:                           15
# Date:                Fri, 17 Dec 2021   Pseudo R-squ.:                  0.1326
# Time:                        20:15:13   Log-Likelihood:                -136.42
# converged:                       True   LL-Null:                       -157.28
# Covariance Type:            nonrobust   LLR p-value:                 0.0002483
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept         -266.9855    190.034     -1.405      0.160    -639.445     105.474
# Peak_position       -0.0120      0.010     -1.227      0.220      -0.031       0.007
# Weeks_on_chart       0.0341      0.019      1.820      0.069      -0.003       0.071
# Year                 0.1313      0.094      1.393      0.164      -0.053       0.316
# Acousticness         1.4469      0.916      1.579      0.114      -0.349       3.243
# Duration            1.2e-06   3.69e-06      0.325      0.745   -6.03e-06    8.42e-06
# Energy              -1.1442      1.480     -0.773      0.439      -4.044       1.756
# Explicit            -0.2968      0.514     -0.577      0.564      -1.304       0.711
# Instrumentalness    -8.0974     14.503     -0.558      0.577     -36.524      20.329
# Liveness             0.8269      1.171      0.706      0.480      -1.468       3.122
# Mode                -0.7910      0.365     -2.166      0.030      -1.507      -0.075
# Popularity          -0.0032      0.008     -0.410      0.682      -0.019       0.012
# Speechiness          0.5253      1.861      0.282      0.778      -3.123       4.173
# Tempo                0.0123      0.006      2.032      0.042       0.000       0.024
# TimeSignature       -0.2844      0.722     -0.394      0.693      -1.699       1.130
# Valence             -0.7328      0.960     -0.763      0.445      -2.614       1.149
# ====================================================================================

# %%
## removed 'Speechiness' (p-value of .778)
logreg4 = smf.logit(formula = 'Nominated ~ Peak_position + Weeks_on_chart + Year + Acousticness + Duration + Energy + Explicit + Instrumentalness + Liveness + Mode + Popularity + Tempo + TimeSignature + Valence', data=train).fit()
print(logreg4.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.152294
#          Iterations 11
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Nominated   No. Observations:                  896
# Model:                          Logit   Df Residuals:                      881
# Method:                           MLE   Df Model:                           14
# Date:                Fri, 17 Dec 2021   Pseudo R-squ.:                  0.1324
# Time:                        20:15:14   Log-Likelihood:                -136.46
# converged:                       True   LL-Null:                       -157.28
# Covariance Type:            nonrobust   LLR p-value:                 0.0001410
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept         -271.8604    189.494     -1.435      0.151    -643.262      99.541
# Peak_position       -0.0119      0.010     -1.214      0.225      -0.031       0.007
# Weeks_on_chart       0.0345      0.019      1.846      0.065      -0.002       0.071
# Year                 0.1336      0.094      1.422      0.155      -0.051       0.318
# Acousticness         1.4700      0.915      1.606      0.108      -0.324       3.264
# Duration          1.273e-06   3.67e-06      0.347      0.729   -5.93e-06    8.47e-06
# Energy              -1.1342      1.484     -0.764      0.445      -4.042       1.774
# Explicit            -0.2282      0.449     -0.508      0.611      -1.108       0.651
# Instrumentalness    -8.2496     14.773     -0.558      0.577     -37.203      20.704
# Liveness             0.8569      1.166      0.735      0.462      -1.429       3.142
# Mode                -0.7974      0.365     -2.186      0.029      -1.512      -0.083
# Popularity          -0.0031      0.008     -0.396      0.692      -0.019       0.012
# Tempo                0.0125      0.006      2.085      0.037       0.001       0.024
# TimeSignature       -0.2764      0.720     -0.384      0.701      -1.687       1.134
# Valence             -0.7177      0.957     -0.750      0.453      -2.593       1.158
# ====================================================================================

# %%
## removed 'Duration' (p-value of .729)
logreg5 = smf.logit(formula = 'Nominated ~ Peak_position + Weeks_on_chart + Year + Acousticness + Energy + Explicit + Instrumentalness + Liveness + Mode + Popularity + Tempo + TimeSignature + Valence', data=train).fit()
print(logreg5.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.152359
#          Iterations 11
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Nominated   No. Observations:                  896
# Model:                          Logit   Df Residuals:                      882
# Method:                           MLE   Df Model:                           13
# Date:                Fri, 17 Dec 2021   Pseudo R-squ.:                  0.1320
# Time:                        20:15:14   Log-Likelihood:                -136.51
# converged:                       True   LL-Null:                       -157.28
# Covariance Type:            nonrobust   LLR p-value:                 7.828e-05
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept         -267.2540    188.475     -1.418      0.156    -636.657     102.149
# Peak_position       -0.0120      0.010     -1.232      0.218      -0.031       0.007
# Weeks_on_chart       0.0344      0.019      1.848      0.065      -0.002       0.071
# Year                 0.1315      0.094      1.406      0.160      -0.052       0.315
# Acousticness         1.4716      0.913      1.612      0.107      -0.317       3.261
# Energy              -1.1406      1.479     -0.771      0.440      -4.039       1.758
# Explicit            -0.2122      0.446     -0.476      0.634      -1.087       0.662
# Instrumentalness    -7.9485     14.042     -0.566      0.571     -35.471      19.574
# Liveness             0.8728      1.166      0.749      0.454      -1.412       3.158
# Mode                -0.7972      0.365     -2.187      0.029      -1.512      -0.083
# Popularity          -0.0031      0.008     -0.386      0.699      -0.019       0.012
# Tempo                0.0124      0.006      2.073      0.038       0.001       0.024
# TimeSignature       -0.2609      0.720     -0.362      0.717      -1.672       1.150
# Valence             -0.7751      0.942     -0.823      0.410      -2.621       1.070
# ====================================================================================

# %%
## removed 'Popularity' (p-value of .699)
logreg6 = smf.logit(formula = 'Nominated ~ Peak_position + Weeks_on_chart + Year + Acousticness + Energy + Explicit + Instrumentalness + Liveness + Mode + Tempo + TimeSignature + Valence', data=train).fit()
print(logreg6.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.152441
#          Iterations 11
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Nominated   No. Observations:                  896
# Model:                          Logit   Df Residuals:                      883
# Method:                           MLE   Df Model:                           12
# Date:                Fri, 17 Dec 2021   Pseudo R-squ.:                  0.1315
# Time:                        20:15:14   Log-Likelihood:                -136.59
# converged:                       True   LL-Null:                       -157.28
# Covariance Type:            nonrobust   LLR p-value:                 4.237e-05
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept         -251.6438    183.125     -1.374      0.169    -610.562     107.274
# Peak_position       -0.0118      0.010     -1.207      0.227      -0.031       0.007
# Weeks_on_chart       0.0341      0.019      1.831      0.067      -0.002       0.071
# Year                 0.1237      0.091      1.362      0.173      -0.054       0.302
# Acousticness         1.5092      0.905      1.667      0.096      -0.265       3.284
# Energy              -1.0642      1.462     -0.728      0.467      -3.930       1.802
# Explicit            -0.2217      0.445     -0.498      0.618      -1.094       0.651
# Instrumentalness    -7.9069     13.962     -0.566      0.571     -35.271      19.457
# Liveness             0.8856      1.168      0.758      0.448      -1.404       3.175
# Mode                -0.7917      0.364     -2.176      0.030      -1.505      -0.079
# Tempo                0.0123      0.006      2.074      0.038       0.001       0.024
# TimeSignature       -0.2841      0.716     -0.397      0.692      -1.688       1.120
# Valence             -0.7828      0.941     -0.832      0.405      -2.626       1.061
# ====================================================================================

# %%
## removed 'TimeSignature' (p-value of .692)
logreg7 = smf.logit(formula = 'Nominated ~ Peak_position + Weeks_on_chart + Year + Acousticness + Energy + Explicit + Instrumentalness + Liveness + Mode + Tempo + Valence', data=train).fit()
print(logreg7.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.152527
#          Iterations 11
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Nominated   No. Observations:                  896
# Model:                          Logit   Df Residuals:                      884
# Method:                           MLE   Df Model:                           11
# Date:                Fri, 17 Dec 2021   Pseudo R-squ.:                  0.1311
# Time:                        20:15:14   Log-Likelihood:                -136.66
# converged:                       True   LL-Null:                       -157.28
# Covariance Type:            nonrobust   LLR p-value:                 2.205e-05
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept         -254.1269    182.923     -1.389      0.165    -612.649     104.395
# Peak_position       -0.0118      0.010     -1.221      0.222      -0.031       0.007
# Weeks_on_chart       0.0336      0.019      1.811      0.070      -0.003       0.070
# Year                 0.1244      0.091      1.370      0.171      -0.054       0.302
# Acousticness         1.5578      0.894      1.743      0.081      -0.194       3.310
# Energy              -1.1314      1.447     -0.782      0.434      -3.967       1.704
# Explicit            -0.2193      0.443     -0.495      0.621      -1.088       0.650
# Instrumentalness    -7.5022     12.883     -0.582      0.560     -32.753      17.748
# Liveness             0.9281      1.161      0.799      0.424      -1.347       3.204
# Mode                -0.7927      0.364     -2.179      0.029      -1.506      -0.080
# Tempo                0.0128      0.006      2.204      0.028       0.001       0.024
# Valence             -0.8215      0.934     -0.880      0.379      -2.652       1.009
# ====================================================================================

# %%
## removed 'Explicit' (p-value of .621)
logreg8 = smf.logit(formula = 'Nominated ~ Peak_position + Weeks_on_chart + Year + Acousticness + Energy + Instrumentalness + Liveness + Mode + Tempo + Valence', data=train).fit()
print(logreg8.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.152667
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Nominated   No. Observations:                  896
# Model:                          Logit   Df Residuals:                      885
# Method:                           MLE   Df Model:                           10
# Date:                Fri, 17 Dec 2021   Pseudo R-squ.:                  0.1303
# Time:                        20:15:15   Log-Likelihood:                -136.79
# converged:                       True   LL-Null:                       -157.28
# Covariance Type:            nonrobust   LLR p-value:                 1.141e-05
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept         -247.2498    182.861     -1.352      0.176    -605.650     111.150
# Peak_position       -0.0118      0.010     -1.219      0.223      -0.031       0.007
# Weeks_on_chart       0.0350      0.018      1.909      0.056      -0.001       0.071
# Year                 0.1208      0.091      1.332      0.183      -0.057       0.299
# Acousticness         1.6263      0.877      1.855      0.064      -0.092       3.345
# Energy              -1.0296      1.427     -0.722      0.471      -3.826       1.767
# Instrumentalness    -7.1229     11.957     -0.596      0.551     -30.559      16.313
# Liveness             0.8418      1.149      0.733      0.464      -1.409       3.093
# Mode                -0.7692      0.360     -2.137      0.033      -1.475      -0.064
# Tempo                0.0131      0.006      2.264      0.024       0.002       0.024
# Valence             -0.8113      0.933     -0.870      0.384      -2.640       1.017
# ====================================================================================

# %%
## removed 'Instrumentalness' (p-value of .551)
logreg9 = smf.logit(formula = 'Nominated ~ Peak_position + Weeks_on_chart + Year + Acousticness + Energy + Liveness + Mode + Tempo + Valence', data=train).fit()
print(logreg9.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.153521
#          Iterations 9
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Nominated   No. Observations:                  896
# Model:                          Logit   Df Residuals:                      886
# Method:                           MLE   Df Model:                            9
# Date:                Fri, 17 Dec 2021   Pseudo R-squ.:                  0.1254
# Time:                        20:15:15   Log-Likelihood:                -137.55
# converged:                       True   LL-Null:                       -157.28
# Covariance Type:            nonrobust   LLR p-value:                 9.586e-06
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       -242.3866    183.271     -1.323      0.186    -601.592     116.819
# Peak_position     -0.0133      0.009     -1.408      0.159      -0.032       0.005
# Weeks_on_chart     0.0301      0.017      1.779      0.075      -0.003       0.063
# Year               0.1185      0.091      1.303      0.193      -0.060       0.297
# Acousticness       1.5914      0.881      1.807      0.071      -0.135       3.318
# Energy            -0.9578      1.430     -0.670      0.503      -3.761       1.846
# Liveness           0.8050      1.149      0.701      0.483      -1.447       3.057
# Mode              -0.7758      0.360     -2.155      0.031      -1.481      -0.070
# Tempo              0.0133      0.006      2.293      0.022       0.002       0.025
# Valence           -0.7544      0.927     -0.814      0.416      -2.571       1.063
# ==================================================================================

# %%
## removed 'Energy' (p-value of .503)
logreg10 = smf.logit(formula = 'Nominated ~ Peak_position + Weeks_on_chart + Year + Acousticness + Liveness + Mode + Tempo + Valence', data=train).fit()
print(logreg10.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.153770
#          Iterations 9
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Nominated   No. Observations:                  896
# Model:                          Logit   Df Residuals:                      887
# Method:                           MLE   Df Model:                            8
# Date:                Fri, 17 Dec 2021   Pseudo R-squ.:                  0.1240
# Time:                        20:15:16   Log-Likelihood:                -137.78
# converged:                       True   LL-Null:                       -157.28
# Covariance Type:            nonrobust   LLR p-value:                 4.924e-06
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       -269.7700    178.240     -1.514      0.130    -619.114      79.574
# Peak_position     -0.0137      0.009     -1.450      0.147      -0.032       0.005
# Weeks_on_chart     0.0309      0.017      1.821      0.069      -0.002       0.064
# Year               0.1318      0.089      1.489      0.137      -0.042       0.305
# Acousticness       1.9467      0.708      2.751      0.006       0.560       3.334
# Liveness           0.7027      1.138      0.617      0.537      -1.528       2.934
# Mode              -0.7844      0.359     -2.185      0.029      -1.488      -0.081
# Tempo              0.0134      0.006      2.298      0.022       0.002       0.025
# Valence           -1.0461      0.824     -1.270      0.204      -2.661       0.569
# ==================================================================================

# %%
## removed 'Liveness' (p-value of .537)
logreg11 = smf.logit(formula = 'Nominated ~ Peak_position + Weeks_on_chart + Year +\
                                Acousticness + Mode + Tempo + Valence', data=train).fit()
print(logreg11.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.153972
#          Iterations 9
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Nominated   No. Observations:                  896
# Model:                          Logit   Df Residuals:                      888
# Method:                           MLE   Df Model:                            7
# Date:                Fri, 17 Dec 2021   Pseudo R-squ.:                  0.1228
# Time:                        20:15:17   Log-Likelihood:                -137.96
# converged:                       True   LL-Null:                       -157.28
# Covariance Type:            nonrobust   LLR p-value:                 2.294e-06
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       -261.3745    177.588     -1.472      0.141    -609.440      86.691
# Peak_position     -0.0142      0.009     -1.495      0.135      -0.033       0.004
# Weeks_on_chart     0.0294      0.017      1.751      0.080      -0.004       0.062
# Year               0.1277      0.088      1.448      0.148      -0.045       0.301
# Acousticness       1.8920      0.700      2.704      0.007       0.520       3.264
# Mode              -0.7775      0.359     -2.166      0.030      -1.481      -0.074
# Tempo              0.0135      0.006      2.324      0.020       0.002       0.025
# Valence           -1.0359      0.823     -1.258      0.208      -2.650       0.578
# ==================================================================================

# %%
y_prob = logreg11.predict(c_xte)
y_pred = pd.Series([1 if x > 0.5 else 0 for x in y_prob], index = y_prob.index)

cm = confusion_matrix(c_yte, y_pred)
print ("Confusion Matrix : \n", cm)
# Out:
# Confusion Matrix :
#  [[177   0]
#  [ 20   0]]

# %%
acc = (cm.ravel()[0]+cm.ravel()[3])/sum(cm.ravel())
print('Accuracy on testing: ', acc)
# Out:
# Accuracy on testing:  0.8984771573604061

# %%
y_prob = logreg11.predict(c_xte)
y_pred = pd.Series([1 if x > 0.17 else 0 for x in y_prob], index = y_prob.index)

cm = confusion_matrix(c_yte, y_pred)
print ("Confusion Matrix : \n", cm)
# Out:
# Confusion Matrix :
#  [[167  10]
#  [ 17   3]]

# %%
acc = (cm.ravel()[0]+cm.ravel()[3])/sum(cm.ravel())
print('Accuracy on testing: ', acc)
# Out:
# Accuracy on testing:  0.8629441624365483

# %%
fpr, tpr, _ = roc_curve(c_yte, y_pred)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8,6))
plt.title('ROC Curve', fontsize=18)
plt.xlabel('FPR', fontsize=16)
plt.ylabel('TPR', fontsize=16)
plt.xlim([-.01, 1.00])
plt.ylim([-.01, 1.01])
plt.plot(fpr, tpr, lw=3, label='Logistic Regression (0.17 cutoff) (area = {:0.2f})'.format(roc_auc))
plt.plot([0,1], [0,1], color='navy', lw=3, linestyle='--', label='Logistic Regression (0.50 cutoff) (area = 0.50)')
plt.legend(loc='lower right', fontsize=14)
plt.show()

# %%
indices = c_xte.index

y_pred_res = y_pred.astype('bool').to_numpy()
frame = {'Index':indices, 'Grammy_Nominated_Logistic':y_pred_res}
log_result = pd.DataFrame(frame)
log_result.head()
# Out:
#    Index  Grammy_Nominated_Logistic
# 0      0                      False
# 1      1                      False
# 2      2                      False
# 3      3                       True
# 4      4                      False

# %%
log_result.to_csv('LogisticPredictions.csv', index=False)

# %% [markdown]
# # Neural Network

# %%
music = pd.read_csv('music_data.csv')

train = music[music["Year"] <= 2016]
test = music[music["Year"] >= 2017]

#regression -- predict peak position 
r_ytr = train["Peak_position"]
r_xtr = train.drop(columns = ["Peak_position"])
r_yte = test["Peak_position"]
r_xte = test.drop(columns = ["Peak_position"])

#classification -- predict whether or not the song will win a grammy 
c_ytr = train["Nominated"]
c_xtr = train.drop(columns = ["Nominated"])
c_yte = test["Nominated"]
c_xte = test.drop(columns = ["Nominated"])

# %% [markdown]
# ## Regression

# %%
import scipy.stats as stats
label = preprocessing.LabelEncoder()

y_train = label.fit_transform(r_ytr)
y_test = label.fit_transform(r_yte)

x_train = r_xtr[['Weeks_on_chart', 'Year', 'Danceability', 'Energy', 'Explicit', 
                 'Liveness', 'Mode', 'Popularity', 'Tempo', 'Grammy']]

x_train['Weeks_on_chart'] = label.fit_transform(x_train['Weeks_on_chart'])
x_train['Year'] = label.fit_transform(x_train['Year'])
x_train['Danceability'] = label.fit_transform(x_train['Danceability'])
x_train['Energy'] = label.fit_transform(x_train['Energy'])
x_train['Liveness'] = label.fit_transform(x_train['Liveness'])
x_train['Popularity'] = label.fit_transform(x_train['Popularity'])
x_train['Tempo'] = label.fit_transform(x_train['Tempo'])

x_test = r_xte[['Weeks_on_chart', 'Year', 'Danceability', 'Energy', 'Explicit', 
                'Liveness', 'Mode', 'Popularity', 'Tempo', 'Grammy']]

x_test['Weeks_on_chart'] = label.fit_transform(x_test['Weeks_on_chart'])
x_test['Year'] = label.fit_transform(x_test['Year'])
x_test['Danceability'] = label.fit_transform(x_test['Danceability'])
x_test['Energy'] = label.fit_transform(x_test['Energy'])
x_test['Liveness'] = label.fit_transform(x_test['Liveness'])
x_test['Popularity'] = label.fit_transform(x_test['Popularity'])
x_test['Tempo'] = label.fit_transform(x_test['Tempo'])

clf = MLPClassifier(hidden_layer_sizes=(50,100,150), max_iter= 200,
                     solver='lbfgs', verbose=1,  random_state=43) 
clf.fit(x_train, y_train)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =        35598     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.31808D+01    |proj g|=  5.09822D+01
#
# At iterate    1    f=  3.26015D+01    |proj g|=  4.14898D+01
#
# At iterate    2    f=  2.99757D+01    |proj g|=  5.14563D+01
#
# At iterate    3    f=  2.53548D+01    |proj g|=  2.75087D+01
#
# At iterate    4    f=  1.86166D+01    |proj g|=  1.43376D+01
#  This problem is unconstrained.
# At iterate    5    f=  1.59589D+01    |proj g|=  7.74767D+00
#
# At iterate    6    f=  1.42277D+01    |proj g|=  6.14369D+00
#
# At iterate    7    f=  1.25404D+01    |proj g|=  6.33157D+00
#
# At iterate    8    f=  1.05436D+01    |proj g|=  5.23862D+00
#
# At iterate    9    f=  8.36293D+00    |proj g|=  3.18755D+00
#
# At iterate   10    f=  7.04134D+00    |proj g|=  4.09644D+00
#
# At iterate   11    f=  5.96547D+00    |proj g|=  2.36660D+00
#
# At iterate   12    f=  5.14630D+00    |proj g|=  2.11271D+00
#
# At iterate   13    f=  4.78784D+00    |proj g|=  7.67203D-01
#
# At iterate   14    f=  4.65908D+00    |proj g|=  4.01786D-01
#
# At iterate   15    f=  4.58364D+00    |proj g|=  6.33876D-01
#
# At iterate   16    f=  4.53317D+00    |proj g|=  3.20440D-01
#
# At iterate   17    f=  4.50850D+00    |proj g|=  1.63389D-01
#
# At iterate   18    f=  4.48720D+00    |proj g|=  3.36658D-01
#
# At iterate   19    f=  4.46551D+00    |proj g|=  3.16685D-01
#
# At iterate   20    f=  4.44203D+00    |proj g|=  6.55609D-01
#
# At iterate   21    f=  4.42769D+00    |proj g|=  1.64007D-01
#
# At iterate   22    f=  4.41736D+00    |proj g|=  4.17601D-01
#
# At iterate   23    f=  4.40566D+00    |proj g|=  5.81589D-01
#
# At iterate   24    f=  4.38926D+00    |proj g|=  2.58975D-01
#
# At iterate   25    f=  4.37075D+00    |proj g|=  5.35427D-01
#
# At iterate   26    f=  4.34819D+00    |proj g|=  5.64779D-01
#
# At iterate   27    f=  4.33466D+00    |proj g|=  3.28323D-01
#
# At iterate   28    f=  4.32640D+00    |proj g|=  3.35060D-01
#
# At iterate   29    f=  4.31510D+00    |proj g|=  2.99841D-01
#
# At iterate   30    f=  4.28632D+00    |proj g|=  2.90435D-01
#
# At iterate   31    f=  4.27170D+00    |proj g|=  1.04270D+00
#
# At iterate   32    f=  4.24489D+00    |proj g|=  8.26438D-01
#
# At iterate   33    f=  4.22541D+00    |proj g|=  7.04783D-01
#
# At iterate   34    f=  4.21317D+00    |proj g|=  3.94984D-01
#
# At iterate   35    f=  4.20097D+00    |proj g|=  3.67805D-01
#
# At iterate   36    f=  4.18220D+00    |proj g|=  8.75761D-01
#
# At iterate   37    f=  4.16043D+00    |proj g|=  4.18743D-01
#
# At iterate   38    f=  4.14420D+00    |proj g|=  4.50583D-01
#
# At iterate   39    f=  4.12521D+00    |proj g|=  8.03509D-01
#
# At iterate   40    f=  4.11044D+00    |proj g|=  5.85559D-01
#
# At iterate   41    f=  4.08909D+00    |proj g|=  2.80777D-01
#
# At iterate   42    f=  4.06366D+00    |proj g|=  7.71720D-01
#
# At iterate   43    f=  4.04946D+00    |proj g|=  5.59587D-01
#
# At iterate   44    f=  4.03532D+00    |proj g|=  4.17725D-01
#
# At iterate   45    f=  4.01984D+00    |proj g|=  6.37219D-01
#
# At iterate   46    f=  4.00761D+00    |proj g|=  1.58045D+00
#
# At iterate   47    f=  3.99804D+00    |proj g|=  4.95740D-01
#
# At iterate   48    f=  3.99149D+00    |proj g|=  9.84616D-01
#
# At iterate   49    f=  3.98125D+00    |proj g|=  7.72794D-01
#
# At iterate   50    f=  3.96050D+00    |proj g|=  6.98793D-01
#
# At iterate   51    f=  3.94696D+00    |proj g|=  8.82375D-01
#
# At iterate   52    f=  3.93521D+00    |proj g|=  7.89965D-01
#
# At iterate   53    f=  3.92543D+00    |proj g|=  3.22121D-01
#
# At iterate   54    f=  3.91218D+00    |proj g|=  3.60916D-01
#
# At iterate   55    f=  3.89911D+00    |proj g|=  6.19911D-01
#
# At iterate   56    f=  3.88838D+00    |proj g|=  4.67471D-01
#
# At iterate   57    f=  3.87672D+00    |proj g|=  1.44187D+00
#
# At iterate   58    f=  3.87031D+00    |proj g|=  1.95256D+00
#
# At iterate   59    f=  3.86330D+00    |proj g|=  8.28563D-01
#
# At iterate   60    f=  3.85681D+00    |proj g|=  4.56468D-01
#
# At iterate   61    f=  3.84775D+00    |proj g|=  3.69648D-01
#
# At iterate   62    f=  3.83193D+00    |proj g|=  3.71925D-01
#
# At iterate   63    f=  3.81475D+00    |proj g|=  1.11766D+00
#
# At iterate   64    f=  3.79832D+00    |proj g|=  4.31111D-01
#
# At iterate   65    f=  3.78198D+00    |proj g|=  3.67458D-01
#
# At iterate   66    f=  3.76104D+00    |proj g|=  7.05184D-01
#
# At iterate   67    f=  3.75209D+00    |proj g|=  8.02068D-01
#
# At iterate   68    f=  3.74324D+00    |proj g|=  5.40098D-01
#
# At iterate   69    f=  3.73395D+00    |proj g|=  3.09333D-01
#
# At iterate   70    f=  3.73087D+00    |proj g|=  1.55488D+00
#
# At iterate   71    f=  3.72276D+00    |proj g|=  5.89013D-01
#
# At iterate   72    f=  3.71631D+00    |proj g|=  7.09467D-01
#
# At iterate   73    f=  3.69993D+00    |proj g|=  7.07563D-01
#
# At iterate   74    f=  3.67975D+00    |proj g|=  9.42813D-01
#
# At iterate   75    f=  3.66599D+00    |proj g|=  1.34833D+00
#
# At iterate   76    f=  3.65450D+00    |proj g|=  5.05139D-01
#
# At iterate   77    f=  3.64698D+00    |proj g|=  5.38946D-01
#
# At iterate   78    f=  3.63485D+00    |proj g|=  4.45405D-01
#
# At iterate   79    f=  3.62922D+00    |proj g|=  9.61953D-01
#
# At iterate   80    f=  3.60410D+00    |proj g|=  4.24212D-01
#
# At iterate   81    f=  3.59373D+00    |proj g|=  1.21593D+00
#
# At iterate   82    f=  3.58983D+00    |proj g|=  9.72936D-01
#
# At iterate   83    f=  3.58203D+00    |proj g|=  8.67967D-01
#
# At iterate   84    f=  3.56753D+00    |proj g|=  9.14000D-01
#
# At iterate   85    f=  3.55335D+00    |proj g|=  4.48768D-01
#
# At iterate   86    f=  3.53988D+00    |proj g|=  1.05841D+00
#
# At iterate   87    f=  3.52576D+00    |proj g|=  7.46953D-01
#
# At iterate   88    f=  3.49981D+00    |proj g|=  9.94206D-01
#
# At iterate   89    f=  3.48559D+00    |proj g|=  7.80625D-01
#
# At iterate   90    f=  3.47236D+00    |proj g|=  4.81552D-01
#
# At iterate   91    f=  3.44554D+00    |proj g|=  4.05053D-01
#
# At iterate   92    f=  3.42206D+00    |proj g|=  9.37688D-01
#
# At iterate   93    f=  3.41841D+00    |proj g|=  1.11811D+00
#
# At iterate   94    f=  3.40676D+00    |proj g|=  1.01660D+00
#
# At iterate   95    f=  3.39216D+00    |proj g|=  6.49395D-01
#
# At iterate   96    f=  3.38281D+00    |proj g|=  4.60556D-01
#
# At iterate   97    f=  3.36475D+00    |proj g|=  8.05030D-01
#
# At iterate   98    f=  3.34473D+00    |proj g|=  8.05506D-01
#
# At iterate   99    f=  3.32988D+00    |proj g|=  3.19135D-01
#
# At iterate  100    f=  3.32197D+00    |proj g|=  1.72375D+00
#
# At iterate  101    f=  3.30138D+00    |proj g|=  8.21519D-01
#
# At iterate  102    f=  3.27755D+00    |proj g|=  1.73181D+00
#
# At iterate  103    f=  3.26516D+00    |proj g|=  8.16709D-01
#
# At iterate  104    f=  3.25395D+00    |proj g|=  1.67692D+00
#
# At iterate  105    f=  3.24430D+00    |proj g|=  1.53851D+00
#
# At iterate  106    f=  3.23647D+00    |proj g|=  1.03762D+00
#
# At iterate  107    f=  3.22170D+00    |proj g|=  2.31750D+00
#
# At iterate  108    f=  3.21026D+00    |proj g|=  1.18531D+00
#
# At iterate  109    f=  3.19333D+00    |proj g|=  6.10031D-01
#
# At iterate  110    f=  3.18132D+00    |proj g|=  7.04088D-01
#
# At iterate  111    f=  3.17985D+00    |proj g|=  2.69282D+00
#
# At iterate  112    f=  3.15067D+00    |proj g|=  6.06514D-01
#
# At iterate  113    f=  3.14621D+00    |proj g|=  2.71880D-01
#
# At iterate  114    f=  3.13797D+00    |proj g|=  5.95769D-01
#
# At iterate  115    f=  3.11688D+00    |proj g|=  1.18453D+00
#
# At iterate  116    f=  3.11029D+00    |proj g|=  3.87616D+00
#
# At iterate  117    f=  3.10064D+00    |proj g|=  1.52387D+00
#
# At iterate  118    f=  3.09329D+00    |proj g|=  1.10057D+00
#
# At iterate  119    f=  3.08829D+00    |proj g|=  1.00709D+00
#
# At iterate  120    f=  3.08216D+00    |proj g|=  1.34733D+00
#
# At iterate  121    f=  3.07303D+00    |proj g|=  9.66151D-01
#
# At iterate  122    f=  3.06793D+00    |proj g|=  1.14789D+00
#
# At iterate  123    f=  3.05462D+00    |proj g|=  9.09593D-01
#
# At iterate  124    f=  3.03924D+00    |proj g|=  8.73852D-01
#
# At iterate  125    f=  3.02668D+00    |proj g|=  1.75009D+00
#
# At iterate  126    f=  3.00977D+00    |proj g|=  7.57486D-01
#
# At iterate  127    f=  3.00133D+00    |proj g|=  6.74489D-01
#
# At iterate  128    f=  2.99528D+00    |proj g|=  2.48682D+00
#
# At iterate  129    f=  2.98759D+00    |proj g|=  1.88956D+00
#
# At iterate  130    f=  2.97802D+00    |proj g|=  1.41131D+00
#
# At iterate  131    f=  2.97266D+00    |proj g|=  9.30549D-01
#
# At iterate  132    f=  2.96232D+00    |proj g|=  1.00319D+00
#
# At iterate  133    f=  2.95419D+00    |proj g|=  1.14793D+00
#
# At iterate  134    f=  2.94788D+00    |proj g|=  5.62512D-01
#
# At iterate  135    f=  2.94174D+00    |proj g|=  3.62833D-01
#
# At iterate  136    f=  2.92905D+00    |proj g|=  6.71409D-01
#
# At iterate  137    f=  2.91327D+00    |proj g|=  1.71414D+00
#
# At iterate  138    f=  2.90189D+00    |proj g|=  5.63737D-01
#
# At iterate  139    f=  2.89824D+00    |proj g|=  4.75483D-01
#
# At iterate  140    f=  2.89743D+00    |proj g|=  3.85091D+00
#
# At iterate  141    f=  2.88431D+00    |proj g|=  1.35240D+00
#
# At iterate  142    f=  2.87568D+00    |proj g|=  6.31396D-01
#
# At iterate  143    f=  2.86984D+00    |proj g|=  1.56334D+00
#
# At iterate  144    f=  2.86393D+00    |proj g|=  6.31405D-01
#
# At iterate  145    f=  2.85827D+00    |proj g|=  4.58652D-01
#
# At iterate  146    f=  2.84485D+00    |proj g|=  1.53722D+00
#
# At iterate  147    f=  2.83181D+00    |proj g|=  8.28933D-01
#
# At iterate  148    f=  2.82276D+00    |proj g|=  4.34253D-01
#
# At iterate  149    f=  2.81213D+00    |proj g|=  1.23738D+00
#
# At iterate  150    f=  2.80067D+00    |proj g|=  8.18912D-01
#
# At iterate  151    f=  2.78809D+00    |proj g|=  8.81404D-01
#
# At iterate  152    f=  2.78081D+00    |proj g|=  5.60054D+00
#
# At iterate  153    f=  2.76670D+00    |proj g|=  1.68539D+00
#
# At iterate  154    f=  2.76151D+00    |proj g|=  5.81086D-01
#
# At iterate  155    f=  2.75495D+00    |proj g|=  1.40612D+00
#
# At iterate  156    f=  2.74805D+00    |proj g|=  1.79510D+00
#
# At iterate  157    f=  2.73850D+00    |proj g|=  3.41529D+00
#
# At iterate  158    f=  2.72345D+00    |proj g|=  1.51603D+00
#
# At iterate  159    f=  2.71094D+00    |proj g|=  1.29260D+00
#
# At iterate  160    f=  2.70384D+00    |proj g|=  1.05819D+00
#
# At iterate  161    f=  2.69192D+00    |proj g|=  8.72582D-01
#
# At iterate  162    f=  2.68231D+00    |proj g|=  1.22730D+00
#
# At iterate  163    f=  2.67339D+00    |proj g|=  7.80505D-01
#
# At iterate  164    f=  2.66424D+00    |proj g|=  2.61163D+00
#
# At iterate  165    f=  2.65693D+00    |proj g|=  5.81308D-01
#
# At iterate  166    f=  2.65155D+00    |proj g|=  8.61628D-01
#
# At iterate  167    f=  2.63922D+00    |proj g|=  1.37345D+00
#
# At iterate  168    f=  2.62153D+00    |proj g|=  2.34266D+00
#
# At iterate  169    f=  2.61110D+00    |proj g|=  1.42338D+00
#
# At iterate  170    f=  2.60363D+00    |proj g|=  9.19115D-01
#
# At iterate  171    f=  2.59201D+00    |proj g|=  7.60838D-01
#
# At iterate  172    f=  2.57552D+00    |proj g|=  2.79102D+00
#
# At iterate  173    f=  2.55929D+00    |proj g|=  1.68233D+00
#
# At iterate  174    f=  2.54111D+00    |proj g|=  1.10624D+00
#
# At iterate  175    f=  2.53446D+00    |proj g|=  7.52662D-01
#
# At iterate  176    f=  2.51579D+00    |proj g|=  9.36117D-01
#
# At iterate  177    f=  2.50347D+00    |proj g|=  4.86257D-01
#
# At iterate  178    f=  2.48728D+00    |proj g|=  2.38200D+00
#
# At iterate  179    f=  2.48083D+00    |proj g|=  2.45157D+00
#
# At iterate  180    f=  2.47400D+00    |proj g|=  1.08905D+00
#
# At iterate  181    f=  2.46979D+00    |proj g|=  7.25535D-01
#
# At iterate  182    f=  2.46158D+00    |proj g|=  1.07443D+00
#
# At iterate  183    f=  2.45216D+00    |proj g|=  6.96764D-01
#
# At iterate  184    f=  2.44394D+00    |proj g|=  1.94939D+00
#
# At iterate  185    f=  2.42828D+00    |proj g|=  1.35886D+00
#
# At iterate  186    f=  2.41613D+00    |proj g|=  1.20736D+00
#
# At iterate  187    f=  2.40199D+00    |proj g|=  1.57592D+00
#
# At iterate  188    f=  2.38918D+00    |proj g|=  4.17895D-01
#
# At iterate  189    f=  2.37889D+00    |proj g|=  7.69417D-01
#
# At iterate  190    f=  2.37010D+00    |proj g|=  1.96365D+00
#
# At iterate  191    f=  2.36603D+00    |proj g|=  1.13411D+00
#
# At iterate  192    f=  2.36368D+00    |proj g|=  9.76782D-01
#
# At iterate  193    f=  2.35532D+00    |proj g|=  1.65819D+00
#
# At iterate  194    f=  2.34572D+00    |proj g|=  1.13516D+00
#
# At iterate  195    f=  2.33372D+00    |proj g|=  1.03833D+00
#
# At iterate  196    f=  2.32517D+00    |proj g|=  1.66082D+00
#
# At iterate  197    f=  2.31660D+00    |proj g|=  1.60931D+00
#
# At iterate  198    f=  2.30991D+00    |proj g|=  9.63804D-01
#
# At iterate  199    f=  2.30003D+00    |proj g|=  1.26223D+00
#
# At iterate  200    f=  2.29089D+00    |proj g|=  9.13888D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
# 35598    200    211      1     0     0   9.139D-01   2.291D+00
#   F =   2.2908886692627446
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# MLPClassifier(hidden_layer_sizes=(50, 100, 150), random_state=43,
#               solver='lbfgs', verbose=1)

# %%
y_pred_train = clf.predict(x_train)
train_rmse = np.sqrt(mean_squared_error(y_train, y_pred_train))
print('RMSE on training: ', train_rmse)

y_pred_test = clf.predict(x_test)
test_rmse = np.sqrt(mean_squared_error(y_test, y_pred_test))
print('RMSE on testing: ', test_rmse)
# Out:
# RMSE on training:  21.74042790188691
# RMSE on testing:  30.79224637060803

# %% [markdown]
# ## Classification

# %%
import scipy.stats as stats
label = preprocessing.LabelEncoder()

y_train = c_ytr
y_test = c_yte

x_train = c_xtr[['Peak_position', 'Weeks_on_chart', 'Year', 'Acousticness', 'Mode', 'Tempo', 'Valence']]

x_train['Peak_position'] = label.fit_transform(x_train['Peak_position'])
x_train['Weeks_on_chart'] = label.fit_transform(x_train['Weeks_on_chart'])
x_train['Year'] = label.fit_transform(x_train['Year'])
x_train['Acousticness'] = label.fit_transform(x_train['Acousticness'])
x_train['Tempo'] = label.fit_transform(x_train['Tempo'])
x_train['Valence'] = label.fit_transform(x_train['Valence'])

x_test = c_xte[['Peak_position', 'Weeks_on_chart', 'Year', 'Acousticness', 'Mode', 'Tempo', 'Valence']]

x_test['Peak_position'] = label.fit_transform(x_test['Peak_position'])
x_test['Weeks_on_chart'] = label.fit_transform(x_test['Weeks_on_chart'])
x_test['Year'] = label.fit_transform(x_test['Year'])
x_test['Acousticness'] = label.fit_transform(x_test['Acousticness'])
x_test['Tempo'] = label.fit_transform(x_test['Tempo'])
x_test['Valence'] = label.fit_transform(x_test['Valence'])

clf = MLPClassifier(hidden_layer_sizes=(50,100,150), max_iter= 100,
                     solver='lbfgs', verbose=1,  random_state=43)  

clf.fit(x_train, y_train)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =        20801     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.90384D+01    |proj g|=  1.25967D+02
#
# At iterate    1    f=  1.52865D+00    |proj g|=  1.17122D+01
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate    2    f=  7.58709D-01    |proj g|=  4.84020D+00
#
# At iterate    3    f=  7.19497D-01    |proj g|=  2.35804D+00
#
# At iterate    4    f=  5.75410D-01    |proj g|=  1.97243D+00
#
# At iterate    5    f=  3.51439D-01    |proj g|=  8.52531D-01
#
# At iterate    6    f=  2.99013D-01    |proj g|=  1.63968D+00
#
# At iterate    7    f=  2.58819D-01    |proj g|=  6.58283D-01
#
# At iterate    8    f=  2.44830D-01    |proj g|=  7.14647D-01
#
# At iterate    9    f=  2.31892D-01    |proj g|=  5.08408D-01
#
# At iterate   10    f=  2.13941D-01    |proj g|=  3.55540D-01
#
# At iterate   11    f=  1.97550D-01    |proj g|=  2.84568D-01
#
# At iterate   12    f=  1.86002D-01    |proj g|=  1.73603D+00
#
# At iterate   13    f=  1.71462D-01    |proj g|=  2.31289D-01
#
# At iterate   14    f=  1.69877D-01    |proj g|=  1.87557D-01
#
# At iterate   15    f=  1.67678D-01    |proj g|=  2.58521D-01
#
# At iterate   16    f=  1.64303D-01    |proj g|=  1.73994D-01
#
# At iterate   17    f=  1.58391D-01    |proj g|=  1.63391D-01
#
# At iterate   18    f=  1.53078D-01    |proj g|=  1.17045D-01
#
# At iterate   19    f=  1.50134D-01    |proj g|=  3.97319D-01
#
# At iterate   20    f=  1.47294D-01    |proj g|=  1.56996D-01
#
# At iterate   21    f=  1.44540D-01    |proj g|=  1.24512D-01
#
# At iterate   22    f=  1.41760D-01    |proj g|=  1.06622D-01
#
# At iterate   23    f=  1.40845D-01    |proj g|=  1.35381D-01
#
# At iterate   24    f=  1.38419D-01    |proj g|=  2.49615D-01
#
# At iterate   25    f=  1.36752D-01    |proj g|=  1.68595D-01
#
# At iterate   26    f=  1.34485D-01    |proj g|=  8.20027D-02
#
# At iterate   27    f=  1.33354D-01    |proj g|=  1.10283D-01
#
# At iterate   28    f=  1.31249D-01    |proj g|=  8.72826D-02
#
# At iterate   29    f=  1.29213D-01    |proj g|=  1.59142D-01
#
# At iterate   30    f=  1.26759D-01    |proj g|=  9.81047D-02
#
# At iterate   31    f=  1.25406D-01    |proj g|=  1.41662D-01
#
# At iterate   32    f=  1.23592D-01    |proj g|=  1.52413D-01
#
# At iterate   33    f=  1.21134D-01    |proj g|=  2.30188D-01
#
# At iterate   34    f=  1.19844D-01    |proj g|=  1.57987D-01
#
# At iterate   35    f=  1.18809D-01    |proj g|=  1.15729D-01
#
# At iterate   36    f=  1.18089D-01    |proj g|=  1.35182D-01
#
# At iterate   37    f=  1.16799D-01    |proj g|=  8.19071D-02
#
# At iterate   38    f=  1.15591D-01    |proj g|=  6.02029D-02
#
# At iterate   39    f=  1.14698D-01    |proj g|=  2.07600D-01
#
# At iterate   40    f=  1.13583D-01    |proj g|=  8.85515D-02
#
# At iterate   41    f=  1.13146D-01    |proj g|=  5.30405D-02
#
# At iterate   42    f=  1.12337D-01    |proj g|=  8.63636D-02
#
# At iterate   43    f=  1.11311D-01    |proj g|=  1.71235D-01
#
# At iterate   44    f=  1.09678D-01    |proj g|=  8.20121D-02
#
# At iterate   45    f=  1.08631D-01    |proj g|=  2.34475D-01
#
# At iterate   46    f=  1.07867D-01    |proj g|=  1.62584D-01
#
# At iterate   47    f=  1.07455D-01    |proj g|=  1.04250D-01
#
# At iterate   48    f=  1.06968D-01    |proj g|=  5.91283D-02
#
# At iterate   49    f=  1.05881D-01    |proj g|=  6.59462D-02
#
# At iterate   50    f=  1.05191D-01    |proj g|=  1.33035D-01
#
# At iterate   51    f=  1.03641D-01    |proj g|=  1.53047D-01
#
# At iterate   52    f=  1.02827D-01    |proj g|=  7.68109D-02
#
# At iterate   53    f=  1.01931D-01    |proj g|=  7.08331D-02
#
# At iterate   54    f=  1.00919D-01    |proj g|=  1.05711D-01
#
# At iterate   55    f=  1.00027D-01    |proj g|=  9.39145D-02
#
# At iterate   56    f=  9.90627D-02    |proj g|=  8.47095D-02
#
# At iterate   57    f=  9.79686D-02    |proj g|=  6.32696D-02
#
# At iterate   58    f=  9.78728D-02    |proj g|=  2.77807D-01
#
# At iterate   59    f=  9.65937D-02    |proj g|=  8.61919D-02
#
# At iterate   60    f=  9.63673D-02    |proj g|=  1.39604D-01
#
# At iterate   61    f=  9.54961D-02    |proj g|=  1.27523D-01
#
# At iterate   62    f=  9.42609D-02    |proj g|=  2.18120D-01
#
# At iterate   63    f=  9.33860D-02    |proj g|=  7.98000D-02
#
# At iterate   64    f=  9.27036D-02    |proj g|=  6.35069D-02
#
# At iterate   65    f=  9.20854D-02    |proj g|=  6.17426D-02
#
# At iterate   66    f=  9.15003D-02    |proj g|=  1.04385D-01
#
# At iterate   67    f=  8.98830D-02    |proj g|=  8.78132D-02
#
# At iterate   68    f=  8.84041D-02    |proj g|=  6.32738D-02
#
# At iterate   69    f=  8.77145D-02    |proj g|=  8.88871D-02
#
# At iterate   70    f=  8.67608D-02    |proj g|=  1.43674D-01
#
# At iterate   71    f=  8.63471D-02    |proj g|=  1.21882D-01
#
# At iterate   72    f=  8.59871D-02    |proj g|=  6.98843D-02
#
# At iterate   73    f=  8.54031D-02    |proj g|=  5.30476D-02
#
# At iterate   74    f=  8.48464D-02    |proj g|=  6.60985D-02
#
# At iterate   75    f=  8.41614D-02    |proj g|=  9.55597D-02
#
# At iterate   76    f=  8.32542D-02    |proj g|=  1.35478D-01
#
# At iterate   77    f=  8.20715D-02    |proj g|=  1.07682D-01
#
# At iterate   78    f=  8.10705D-02    |proj g|=  8.84807D-02
#
# At iterate   79    f=  8.04623D-02    |proj g|=  6.12842D-02
#
# At iterate   80    f=  7.99075D-02    |proj g|=  1.05998D-01
#
# At iterate   81    f=  7.92429D-02    |proj g|=  9.36694D-02
#
# At iterate   82    f=  7.85242D-02    |proj g|=  6.87284D-02
#
# At iterate   83    f=  7.78762D-02    |proj g|=  2.21130D-01
#
# At iterate   84    f=  7.72871D-02    |proj g|=  8.22451D-02
#
# At iterate   85    f=  7.70146D-02    |proj g|=  7.65111D-02
#
# At iterate   86    f=  7.65872D-02    |proj g|=  7.80741D-02
#
# At iterate   87    f=  7.57663D-02    |proj g|=  7.83749D-02
#
# At iterate   88    f=  7.48727D-02    |proj g|=  1.06251D-01
#
# At iterate   89    f=  7.41705D-02    |proj g|=  8.99593D-02
#
# At iterate   90    f=  7.36601D-02    |proj g|=  1.01047D-01
#
# At iterate   91    f=  7.28038D-02    |proj g|=  8.63181D-02
#
# At iterate   92    f=  7.19240D-02    |proj g|=  7.14143D-02
#
# At iterate   93    f=  7.11455D-02    |proj g|=  7.49189D-02
#
# At iterate   94    f=  7.07934D-02    |proj g|=  1.63898D-01
#
# At iterate   95    f=  7.01283D-02    |proj g|=  1.25991D-01
#
# At iterate   96    f=  6.97194D-02    |proj g|=  7.99099D-02
#
# At iterate   97    f=  6.91859D-02    |proj g|=  8.84741D-02
#
# At iterate   98    f=  6.88724D-02    |proj g|=  8.37549D-02
#
# At iterate   99    f=  6.83012D-02    |proj g|=  1.43093D-01
#
# At iterate  100    f=  6.79198D-02    |proj g|=  9.15159D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
# 20801    100    131      2     0     0   9.152D-02   6.792D-02
#   F =   6.7919756800854172E-002
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# MLPClassifier(hidden_layer_sizes=(50, 100, 150), max_iter=100, random_state=43,
#               solver='lbfgs', verbose=1)

# %%
y_pred_train = clf.predict(x_train)
train_accuracy = accuracy_score(y_train, y_pred_train)
print('Accuracy on training: ', train_accuracy)

y_pred_test = clf.predict(x_test)
test_accuracy = accuracy_score(y_test, y_pred_test)
print('Accuracy on testing: ', test_accuracy)
# Out:
# Accuracy on training:  0.9776785714285714
# Accuracy on testing:  0.8934010152284264

# %%
indices = c_xte.index

y_pred_res = y_pred_test.astype('bool')
frame = {'Index':indices, 'Grammy_Nominated_NeuralNetwork':y_pred_res}
nn_result = pd.DataFrame(frame)
nn_result.head()
# Out:
#    Index  Grammy_Nominated_NeuralNetwork
# 0      0                           False
# 1      1                           False
# 2      2                           False
# 3      3                           False
# 4      4                           False

# %%
nn_result.to_csv('NNPredictions.csv', index=False)

# %% [markdown]
# # Decision Tree

# %%
music = pd.read_csv('music_data.csv')

train = music[music["Year"] <= 2016]
test = music[music["Year"] >= 2017]

#regression -- predict peak position 
r_ytr = train["Peak_position"]
r_xtr = train.drop(columns = ["Peak_position"])
r_yte = test["Peak_position"]
r_xte = test.drop(columns = ["Peak_position"])

#classification -- predict whether or not the song will win a grammy 
c_ytr = train["Nominated"]
c_xtr = train.drop(columns = ["Nominated"])
c_yte = test["Nominated"]
c_xte = test.drop(columns = ["Nominated"])

# %% [markdown]
# ## Decision Tree Regression

# %%
mse = make_scorer(mean_squared_error)

# %%
y_train = r_ytr
y_test = r_yte
x_train = train[['Weeks_on_chart', 'Year', 'Danceability', 'Energy', 'Explicit', 'Liveness', 'Mode', 'Popularity', 'Tempo', 'Grammy']]
x_test = test[['Weeks_on_chart', 'Year', 'Danceability', 'Energy', 'Explicit', 'Liveness', 'Mode', 'Popularity', 'Tempo', 'Grammy']]

# %%
dt = DecisionTreeClassifier()

grid_values = {'ccp_alpha': np.linspace(0, 0.010, 201),
              'min_samples_leaf': [5],
              'min_samples_split': [20],
              'max_depth': [10],
              'random_state': [42]}
dec_tree_cv = GridSearchCV(dt, param_grid = grid_values, scoring = mse, cv = 10, verbose = 1)
dec_tree_cv.fit(x_train, y_train)
# Out:
# Fitting 10 folds for each of 201 candidates, totalling 2010 fits
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid={'ccp_alpha': array([0.00e+00, 5.00e-05, 1.00e-04, 1.50e-04, 2.00e-04, 2.50e-04,
#        3.00e-04, 3.50e-04, 4.00e-04, 4.50e-04, 5.00e-04, 5.50e-04,
#        6.00e-04, 6.50e-04, 7.00e-04, 7.50e-04, 8.00e-04, 8.50e-04,
#        9.00e-04, 9.50e-04, 1.00e-03, 1.05e-03, 1.10e-03, 1.15e-03,
#        1.20e-03, 1.25e-03, 1.30e-03, 1.35e-03, 1.40e-03, 1.45...
#        8.70e-03, 8.75e-03, 8.80e-03, 8.85e-03, 8.90e-03, 8.95e-03,
#        9.00e-03, 9.05e-03, 9.10e-03, 9.15e-03, 9.20e-03, 9.25e-03,
#        9.30e-03, 9.35e-03, 9.40e-03, 9.45e-03, 9.50e-03, 9.55e-03,
#        9.60e-03, 9.65e-03, 9.70e-03, 9.75e-03, 9.80e-03, 9.85e-03,
#        9.90e-03, 9.95e-03, 1.00e-02]),
#                          'max_depth': [10], 'min_samples_leaf': [5],
#                          'min_samples_split': [20], 'random_state': [42]},
#              scoring=make_scorer(mean_squared_error), verbose=1)

# %%
acc = dec_tree_cv.cv_results_['mean_test_score']
ccp = dec_tree_cv.cv_results_['param_ccp_alpha'].data

alpha_vals = pd.DataFrame({'ccp alpha' : ccp, 'Validation RMSE' : acc**0.5})
lowest_RMSE = alpha_vals[alpha_vals['Validation RMSE'] == min(alpha_vals['Validation RMSE'])]
best_alpha = lowest_RMSE[['ccp alpha']].iloc[0,0]
best_alpha
# Out:
# 0.00405

# %%
dt_updated = DecisionTreeClassifier()
grid_values_updated = {'ccp_alpha': best_alpha,
                       'min_samples_leaf': [5],
                       'min_samples_split': [20],
                       'max_depth': [10],
                       'random_state': [42]}
dec_tree_cv_updated = GridSearchCV(dt_updated, param_grid = grid_values, scoring = mse, cv = 10, verbose = 1)
dec_tree_cv_updated.fit(x_train, y_train)
# Out:
# Fitting 10 folds for each of 201 candidates, totalling 2010 fits
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid={'ccp_alpha': array([0.00e+00, 5.00e-05, 1.00e-04, 1.50e-04, 2.00e-04, 2.50e-04,
#        3.00e-04, 3.50e-04, 4.00e-04, 4.50e-04, 5.00e-04, 5.50e-04,
#        6.00e-04, 6.50e-04, 7.00e-04, 7.50e-04, 8.00e-04, 8.50e-04,
#        9.00e-04, 9.50e-04, 1.00e-03, 1.05e-03, 1.10e-03, 1.15e-03,
#        1.20e-03, 1.25e-03, 1.30e-03, 1.35e-03, 1.40e-03, 1.45...
#        8.70e-03, 8.75e-03, 8.80e-03, 8.85e-03, 8.90e-03, 8.95e-03,
#        9.00e-03, 9.05e-03, 9.10e-03, 9.15e-03, 9.20e-03, 9.25e-03,
#        9.30e-03, 9.35e-03, 9.40e-03, 9.45e-03, 9.50e-03, 9.55e-03,
#        9.60e-03, 9.65e-03, 9.70e-03, 9.75e-03, 9.80e-03, 9.85e-03,
#        9.90e-03, 9.95e-03, 1.00e-02]),
#                          'max_depth': [10], 'min_samples_leaf': [5],
#                          'min_samples_split': [20], 'random_state': [42]},
#              scoring=make_scorer(mean_squared_error), verbose=1)

# %%
y_pred_train = dec_tree_cv_updated.predict(x_train)
train_rmse = np.sqrt(mean_squared_error(y_train, y_pred_train))
print('RMSE on training: ', train_rmse)

y_pred_test = dec_tree_cv_updated.predict(x_test)
test_rmse = np.sqrt(mean_squared_error(y_test, y_pred_test))
print('RMSE on testing: ', test_rmse)
# Out:
# RMSE on training:  22.274990981239156
# RMSE on testing:  24.0835053185037

# %% [markdown]
# ## Decision Tree Classification

# %%
y_train = c_ytr
y_test = c_yte
x_train = train[['Peak_position', 'Weeks_on_chart', 'Year', 'Acousticness', 'Mode', 'Tempo', 'Valence']]
x_test = test[['Peak_position', 'Weeks_on_chart', 'Year', 'Acousticness', 'Mode', 'Tempo', 'Valence']]

# %%
dt = DecisionTreeClassifier()

grid_values = {'ccp_alpha': np.linspace(0, 0.010, 201),
              'min_samples_leaf': [5],
              'min_samples_split': [20],
              'max_depth': [10],
              'random_state': [42]}
dec_tree_cv = GridSearchCV(dt, param_grid = grid_values, scoring = 'accuracy', cv = 10, verbose = 1)
dec_tree_cv.fit(x_train, y_train)
# Out:
# Fitting 10 folds for each of 201 candidates, totalling 2010 fits
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid={'ccp_alpha': array([0.00e+00, 5.00e-05, 1.00e-04, 1.50e-04, 2.00e-04, 2.50e-04,
#        3.00e-04, 3.50e-04, 4.00e-04, 4.50e-04, 5.00e-04, 5.50e-04,
#        6.00e-04, 6.50e-04, 7.00e-04, 7.50e-04, 8.00e-04, 8.50e-04,
#        9.00e-04, 9.50e-04, 1.00e-03, 1.05e-03, 1.10e-03, 1.15e-03,
#        1.20e-03, 1.25e-03, 1.30e-03, 1.35e-03, 1.40e-03, 1.45...
#        8.70e-03, 8.75e-03, 8.80e-03, 8.85e-03, 8.90e-03, 8.95e-03,
#        9.00e-03, 9.05e-03, 9.10e-03, 9.15e-03, 9.20e-03, 9.25e-03,
#        9.30e-03, 9.35e-03, 9.40e-03, 9.45e-03, 9.50e-03, 9.55e-03,
#        9.60e-03, 9.65e-03, 9.70e-03, 9.75e-03, 9.80e-03, 9.85e-03,
#        9.90e-03, 9.95e-03, 1.00e-02]),
#                          'max_depth': [10], 'min_samples_leaf': [5],
#                          'min_samples_split': [20], 'random_state': [42]},
#              scoring='accuracy', verbose=1)

# %%
acc = dec_tree_cv.cv_results_['mean_test_score']
ccp = dec_tree_cv.cv_results_['param_ccp_alpha'].data

alpha_vals = pd.DataFrame({'ccp alpha' : ccp, 'Validation Accuracy' : acc})
highest_acc = alpha_vals[alpha_vals['Validation Accuracy'] == max(alpha_vals['Validation Accuracy'])]
best_alpha = highest_acc[['ccp alpha']].iloc[0,0]
best_alpha
# Out:
# 0.0081

# %%
dt_updated = DecisionTreeClassifier()
grid_values_updated = {'ccp_alpha': best_alpha,
                       'min_samples_leaf': [5],
                       'min_samples_split': [20],
                       'max_depth': [10],
                       'random_state': [42]}
dec_tree_cv_updated = GridSearchCV(dt_updated, param_grid = grid_values, scoring = 'accuracy', cv = 10, verbose = 1)
dec_tree_cv_updated.fit(x_train, y_train)
# Out:
# Fitting 10 folds for each of 201 candidates, totalling 2010 fits
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid={'ccp_alpha': array([0.00e+00, 5.00e-05, 1.00e-04, 1.50e-04, 2.00e-04, 2.50e-04,
#        3.00e-04, 3.50e-04, 4.00e-04, 4.50e-04, 5.00e-04, 5.50e-04,
#        6.00e-04, 6.50e-04, 7.00e-04, 7.50e-04, 8.00e-04, 8.50e-04,
#        9.00e-04, 9.50e-04, 1.00e-03, 1.05e-03, 1.10e-03, 1.15e-03,
#        1.20e-03, 1.25e-03, 1.30e-03, 1.35e-03, 1.40e-03, 1.45...
#        8.70e-03, 8.75e-03, 8.80e-03, 8.85e-03, 8.90e-03, 8.95e-03,
#        9.00e-03, 9.05e-03, 9.10e-03, 9.15e-03, 9.20e-03, 9.25e-03,
#        9.30e-03, 9.35e-03, 9.40e-03, 9.45e-03, 9.50e-03, 9.55e-03,
#        9.60e-03, 9.65e-03, 9.70e-03, 9.75e-03, 9.80e-03, 9.85e-03,
#        9.90e-03, 9.95e-03, 1.00e-02]),
#                          'max_depth': [10], 'min_samples_leaf': [5],
#                          'min_samples_split': [20], 'random_state': [42]},
#              scoring='accuracy', verbose=1)

# %%
y_pred_train = dec_tree_cv_updated.predict(x_train)
train_accuracy = accuracy_score(y_train, y_pred_train)
print('Accuracy on training: ', train_accuracy)

y_pred_test = dec_tree_cv_updated.predict(x_test)
test_accuracy = accuracy_score(y_test, y_pred_test)
print('Accuracy on testing: ', test_accuracy)
# Out:
# Accuracy on training:  0.9575892857142857
# Accuracy on testing:  0.8984771573604061

# %%
indices = c_xte.index

y_pred_res = y_pred_test.astype('bool')
frame = {'Index':indices, 'Grammy_Nominated_DecisionTree':y_pred_res}
dec_tree_result = pd.DataFrame(frame)
dec_tree_result.head()
# Out:
#    Index  Grammy_Nominated_DecisionTree
# 0      0                          False
# 1      1                          False
# 2      2                          False
# 3      3                          False
# 4      4                          False

# %%
dec_tree_result.to_csv('DecisionTreePredictions.csv', index=False)

# %% [markdown]
# # Ensemble Method

# %%
music = pd.read_csv('music_data.csv')

train = music[music["Year"] <= 2016]
test = music[music["Year"] >= 2017]

#regression -- predict peak position 
r_ytr = train["Peak_position"]
r_xtr = train.drop(columns = ["Peak_position"])
r_yte = test["Peak_position"]
r_xte = test.drop(columns = ["Peak_position"])

#classification -- predict whether or not the song will win a grammy 
c_ytr = train["Nominated"]
c_xtr = train.drop(columns = ["Nominated"])
c_yte = test["Nominated"]
c_xte = test.drop(columns = ["Nominated"])

# %%
decision_tree_preds = pd.read_csv("DecisionTreePredictions.csv")
logistic_preds = pd.read_csv("LogisticPredictions.csv")
neural_preds = pd.read_csv("NNPredictions.csv")

# %%
df = pd.DataFrame()
df['Index'] = neural_preds['Index']
df['GrammyNominated_DecisionTree'] = decision_tree_preds['Grammy_Nominated_DecisionTree']
df['GrammyNominated_NeuralNetwork'] = neural_preds['Grammy_Nominated_NeuralNetwork']
df['GrammyNominated_Logistic'] = logistic_preds['Grammy_Nominated_Logistic']
df['Mean'] = (df['GrammyNominated_DecisionTree'] + df['GrammyNominated_NeuralNetwork'] + df['GrammyNominated_Logistic']) / 3
df['GrammyNominated'] = [True if test > 0.5 else False for test in df['Mean']]
df
# Out:
#      Index  GrammyNominated_DecisionTree  GrammyNominated_NeuralNetwork  \
# 0        0                         False                          False
# 1        1                         False                          False
# 2        2                         False                          False
# 3        3                         False                          False
# 4        4                         False                          False
# ..     ...                           ...                            ...
# 192    192                         False                          False
# 193    193                         False                          False
# 194    194                         False                          False
# 195    195                         False                          False
# 196    196                         False                          False
#
#      GrammyNominated_Logistic      Mean  GrammyNominated
# 0                       False  0.000000            False
# 1                       False  0.000000            False
# 2                       False  0.000000            False
# 3                        True  0.333333            False
# 4                       False  0.000000            False
# ..                        ...       ...              ...
# 192                     False  0.000000            False
# 193                     False  0.000000            False
# 194                     False  0.000000            False
# 195                     False  0.000000            False
# 196                     False  0.000000            False
#
# [197 rows x 6 columns]

# %%
final_df = df.loc[:, ['Index', 'GrammyNominated']]
final_df
# Out:
#      Index  GrammyNominated
# 0        0            False
# 1        1            False
# 2        2            False
# 3        3            False
# 4        4            False
# ..     ...              ...
# 192    192            False
# 193    193            False
# 194    194            False
# 195    195            False
# 196    196            False
#
# [197 rows x 2 columns]

# %%
y_true = c_yte.to_numpy()
y_pred = final_df['GrammyNominated'].to_numpy()
print(accuracy_score(y_true, y_pred))
# Out:
# 0.8984771573604061
